# %%
# ! pip show pandas

# %%
import numpy as np
import pandas as pd

# %%
# pd.__version__

# %% [markdown]
# <pre>
#                        1차           2차              3차
#  값(value)    list     Series      DataFrame         Tensor
#  값(value)    행(row)  열(col)     테이블(Table)        -
#  scaler       vector   vector      matrix            tensor
# <img width=500 src="https://miro.medium.com/v2/resize:fit:1100/format:webp/1*OaUbgSxKnC_kaRj0H6vK5Q.jpeg">

# %% [markdown]
# * <b>Series: a one-dimensional</b> labeled array holding data of any type
# such as integers, strings, Python objects etc.
# * <b>DataFrame: a two-dimensional</b> data structure that holds data like a two-dimension array or a table with rows and columns.

# %%
mylist = [1, '2', 3]
s = pd.Series(mylist)
s
# Out:
# 0    1
# 1    2
# 2    3
# dtype: object

# %%
mylist = [1, '글자', 3]
s = pd.Series(mylist)
s
# Out:
# 0     1
# 1    글자
# 2     3
# dtype: object

# %%
type(s[2])
# Out:
# int

# %%
myarray = np.array(mylist)
myarray
# Out:
# array(['1', '글자', '3'], dtype='<U21')

# %%
type(s[0])
# Out:
# int

# %%
mylist = [1, '2', 3]
myarray = np.array(mylist)

df = pd.DataFrame(mylist, myarray)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3 entries, 1 to 3
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   0       3 non-null      object
# dtypes: object(1)
# memory usage: 48.0+ bytes

# %%
df
# Out:
#    0
# 1  1
# 2  2
# 3  3

# %%
s1 = pd.Series([1,2])
s2 = pd.Series(['a','b'])
df3 = pd.concat([s1, s2], axis=1)
print(df3.info())
print(df3)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2 entries, 0 to 1
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   0       2 non-null      int64
#  1   1       2 non-null      object
# dtypes: int64(1), object(1)
# memory usage: 160.0+ bytes
# None
#    0  1
# 0  1  a
# 1  2  b

# %%
s1 = [1,2]
s2 = ['a','b']
df4 = pd.DataFrame([s1, s2])
print(df4.info())
print(df4)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2 entries, 0 to 1
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   0       2 non-null      object
#  1   1       2 non-null      object
# dtypes: object(2)
# memory usage: 160.0+ bytes
# None
#    0  1
# 0  1  2
# 1  a  b

# %% [markdown]
# 날짜 : datetime64[s]
# 실수 : float32/64
# 정수 : int32/64
# 카테 : category
# 글자 : object

# %%
import os
os.getcwd()
# Out:
# 'C:\\IT\\workspace_python\\basic'

# %%
emp = pd.read_csv('./data/emp.csv')

# %%
emp.head()
# Out:
#    EMPNO   ENAME       JOB     MGR             HIREDATE   SAL    COMM  DEPTNO
# 0   7369   SMITH     CLERK  7902.0  1980-12-17 00:00:00   800     NaN      20
# 1   7499   ALLEN  SALESMAN  7698.0  1981-02-20 00:00:00  1600   300.0      30
# 2   7521    WARD  SALESMAN  7698.0  1981-02-22 00:00:00  1250   500.0      30
# 3   7566   JONES   MANAGER  7839.0  1981-04-02 00:00:00  2975     NaN      20
# 4   7654  MARTIN  SALESMAN  7698.0  1981-09-28 00:00:00  1250  1400.0      30

# %%
emp.tail()
# Out:
#     EMPNO   ENAME       JOB     MGR             HIREDATE   SAL  COMM  DEPTNO
# 9    7844  TURNER  SALESMAN  7698.0  1981-09-08 00:00:00  1500   0.0      30
# 10   7876   ADAMS     CLERK  7788.0  1987-07-13 00:00:00  1100   NaN      20
# 11   7900   JAMES     CLERK  7698.0  1981-12-03 00:00:00   950   NaN      30
# 12   7902    FORD   ANALYST  7566.0  1981-12-03 00:00:00  3000   NaN      20
# 13   7934  MILLER     CLERK  7782.0  1982-01-23 00:00:00  1300   NaN      10

# %%
emp.iloc[3:5,[1,5,6]]
# Out:
#     ENAME   SAL    COMM
# 3   JONES  2975     NaN
# 4  MARTIN  1250  1400.0

# %%
emp.loc[3:5, ['ENAME', 'MGR']]
# Out:
#     ENAME     MGR
# 3   JONES  7839.0
# 4  MARTIN  7698.0
# 5   BLAKE  7839.0

# %%
emp.describe()
# Out:
#              EMPNO          MGR          SAL         COMM     DEPTNO
# count    14.000000    13.000000    14.000000     4.000000  14.000000
# mean   7726.571429  7739.307692  2073.214286   550.000000  22.142857
# std     178.294361   103.714660  1182.503224   602.771377   8.017837
# min    7369.000000  7566.000000   800.000000     0.000000  10.000000
# 25%    7588.000000  7698.000000  1250.000000   225.000000  20.000000
# 50%    7785.000000  7698.000000  1550.000000   400.000000  20.000000
# 75%    7868.000000  7839.000000  2943.750000   725.000000  30.000000
# max    7934.000000  7902.000000  5000.000000  1400.000000  30.000000

# %%
emp['DEPTNO'] = emp['DEPTNO'].astype('category')

# %%
emp.describe()
# Out:
#              EMPNO          MGR          SAL         COMM
# count    14.000000    13.000000    14.000000     4.000000
# mean   7726.571429  7739.307692  2073.214286   550.000000
# std     178.294361   103.714660  1182.503224   602.771377
# min    7369.000000  7566.000000   800.000000     0.000000
# 25%    7588.000000  7698.000000  1250.000000   225.000000
# 50%    7785.000000  7698.000000  1550.000000   400.000000
# 75%    7868.000000  7839.000000  2943.750000   725.000000
# max    7934.000000  7902.000000  5000.000000  1400.000000

# %%
emp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14 entries, 0 to 13
# Data columns (total 8 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   EMPNO     14 non-null     int64
#  1   ENAME     14 non-null     object
#  2   JOB       14 non-null     object
#  3   MGR       13 non-null     float64
#  4   HIREDATE  14 non-null     object
#  5   SAL       14 non-null     int64
#  6   COMM      4 non-null      float64
#  7   DEPTNO    14 non-null     category
# dtypes: category(1), float64(2), int64(2), object(3)
# memory usage: 1.0+ KB

# %%
emp.describe(include='all')
# Out:
#               EMPNO  ENAME    JOB          MGR             HIREDATE  \
# count     14.000000     14     14    13.000000                   14
# unique          NaN     14      5          NaN                   12
# top             NaN  SMITH  CLERK          NaN  1981-12-03 00:00:00
# freq            NaN      1      4          NaN                    2
# mean    7726.571429    NaN    NaN  7739.307692                  NaN
# std      178.294361    NaN    NaN   103.714660                  NaN
# min     7369.000000    NaN    NaN  7566.000000                  NaN
# 25%     7588.000000    NaN    NaN  7698.000000                  NaN
# 50%     7785.000000    NaN    NaN  7698.000000                  NaN
# 75%     7868.000000    NaN    NaN  7839.000000                  NaN
# max     7934.000000    NaN    NaN  7902.000000                  NaN
#
#                 SAL         COMM  DEPTNO
# count     14.000000     4.000000    14.0
# unique          NaN          NaN     3.0
# ...

# %%
emp
# Out:
#     EMPNO   ENAME        JOB     MGR             HIREDATE   SAL    COMM DEPTNO
# 0    7369   SMITH      CLERK  7902.0  1980-12-17 00:00:00   800     NaN     20
# 1    7499   ALLEN   SALESMAN  7698.0  1981-02-20 00:00:00  1600   300.0     30
# 2    7521    WARD   SALESMAN  7698.0  1981-02-22 00:00:00  1250   500.0     30
# 3    7566   JONES    MANAGER  7839.0  1981-04-02 00:00:00  2975     NaN     20
# 4    7654  MARTIN   SALESMAN  7698.0  1981-09-28 00:00:00  1250  1400.0     30
# 5    7698   BLAKE    MANAGER  7839.0  1981-05-01 00:00:00  2850     NaN     30
# 6    7782   CLARK    MANAGER  7839.0  1981-06-09 00:00:00  2450     NaN     10
# 7    7788   SCOTT    ANALYST  7566.0  1987-07-13 00:00:00  3000     NaN     20
# 8    7839    KING  PRESIDENT     NaN  1981-11-17 00:00:00  5000     NaN     10
# 9    7844  TURNER   SALESMAN  7698.0  1981-09-08 00:00:00  1500     0.0     30
# 10   7876   ADAMS      CLERK  7788.0  1987-07-13 00:00:00  1100     NaN     20
# ...

# %%
emp.sort_index(ascending = False)
# Out:
#     EMPNO   ENAME        JOB     MGR             HIREDATE   SAL    COMM DEPTNO
# 13   7934  MILLER      CLERK  7782.0  1982-01-23 00:00:00  1300     NaN     10
# 12   7902    FORD    ANALYST  7566.0  1981-12-03 00:00:00  3000     NaN     20
# 11   7900   JAMES      CLERK  7698.0  1981-12-03 00:00:00   950     NaN     30
# 10   7876   ADAMS      CLERK  7788.0  1987-07-13 00:00:00  1100     NaN     20
# 9    7844  TURNER   SALESMAN  7698.0  1981-09-08 00:00:00  1500     0.0     30
# 8    7839    KING  PRESIDENT     NaN  1981-11-17 00:00:00  5000     NaN     10
# 7    7788   SCOTT    ANALYST  7566.0  1987-07-13 00:00:00  3000     NaN     20
# 6    7782   CLARK    MANAGER  7839.0  1981-06-09 00:00:00  2450     NaN     10
# 5    7698   BLAKE    MANAGER  7839.0  1981-05-01 00:00:00  2850     NaN     30
# 4    7654  MARTIN   SALESMAN  7698.0  1981-09-28 00:00:00  1250  1400.0     30
# 3    7566   JONES    MANAGER  7839.0  1981-04-02 00:00:00  2975     NaN     20
# ...

# %%
emp.sort_values('ENAME', ascending = True)
# Out:
#     EMPNO   ENAME        JOB     MGR             HIREDATE   SAL    COMM DEPTNO
# 10   7876   ADAMS      CLERK  7788.0  1987-07-13 00:00:00  1100     NaN     20
# 1    7499   ALLEN   SALESMAN  7698.0  1981-02-20 00:00:00  1600   300.0     30
# 5    7698   BLAKE    MANAGER  7839.0  1981-05-01 00:00:00  2850     NaN     30
# 6    7782   CLARK    MANAGER  7839.0  1981-06-09 00:00:00  2450     NaN     10
# 12   7902    FORD    ANALYST  7566.0  1981-12-03 00:00:00  3000     NaN     20
# 11   7900   JAMES      CLERK  7698.0  1981-12-03 00:00:00   950     NaN     30
# 3    7566   JONES    MANAGER  7839.0  1981-04-02 00:00:00  2975     NaN     20
# 8    7839    KING  PRESIDENT     NaN  1981-11-17 00:00:00  5000     NaN     10
# 4    7654  MARTIN   SALESMAN  7698.0  1981-09-28 00:00:00  1250  1400.0     30
# 13   7934  MILLER      CLERK  7782.0  1982-01-23 00:00:00  1300     NaN     10
# 7    7788   SCOTT    ANALYST  7566.0  1987-07-13 00:00:00  3000     NaN     20
# ...

# %%
emp.sort_values(by = ['DEPTNO', 'SAL'], ascending = [True, False])
# Out:
#     EMPNO   ENAME        JOB     MGR             HIREDATE   SAL    COMM DEPTNO
# 8    7839    KING  PRESIDENT     NaN  1981-11-17 00:00:00  5000     NaN     10
# 6    7782   CLARK    MANAGER  7839.0  1981-06-09 00:00:00  2450     NaN     10
# 13   7934  MILLER      CLERK  7782.0  1982-01-23 00:00:00  1300     NaN     10
# 7    7788   SCOTT    ANALYST  7566.0  1987-07-13 00:00:00  3000     NaN     20
# 12   7902    FORD    ANALYST  7566.0  1981-12-03 00:00:00  3000     NaN     20
# 3    7566   JONES    MANAGER  7839.0  1981-04-02 00:00:00  2975     NaN     20
# 10   7876   ADAMS      CLERK  7788.0  1987-07-13 00:00:00  1100     NaN     20
# 0    7369   SMITH      CLERK  7902.0  1980-12-17 00:00:00   800     NaN     20
# 5    7698   BLAKE    MANAGER  7839.0  1981-05-01 00:00:00  2850     NaN     30
# 1    7499   ALLEN   SALESMAN  7698.0  1981-02-20 00:00:00  1600   300.0     30
# 9    7844  TURNER   SALESMAN  7698.0  1981-09-08 00:00:00  1500     0.0     30
# ...

# %% [markdown]
# <pre><b><font color=red>
#   1개       vs.      1개~
# ----------        ----------
# df.at[]           df.loc[]    ---> 값    "ENAME", 3
# df.iat[]          df.iloc[]   ---> 번째   0  </font>
#
# <font color=blue>(줄     ,    칸)
# - 단일값
# - 슬라이싱 [s:e]   s<= 번째 < e
#           [s:e]   s<= 값 <= e
# - 때거지   [0,1,2,3,5]</font>

# %%
emp.loc[[1,2],'ENAME']
# Out:
# 1    ALLEN
# 2     WARD
# Name: ENAME, dtype: object

# %%
emp.loc[[1,2],'ENAME':'MGR']
# Out:
#    ENAME       JOB     MGR
# 1  ALLEN  SALESMAN  7698.0
# 2   WARD  SALESMAN  7698.0

# %%
emp.iloc[[2,3],1:3]
# Out:
#    ENAME       JOB
# 2   WARD  SALESMAN
# 3  JONES   MANAGER

# %%
emp.loc[1:3, ['ENAME', 'JOB']]
# Out:
#    ENAME       JOB
# 1  ALLEN  SALESMAN
# 2   WARD  SALESMAN
# 3  JONES   MANAGER

# %%
emp.iloc[[1,2,3], 1:3]
# Out:
#    ENAME       JOB
# 1  ALLEN  SALESMAN
# 2   WARD  SALESMAN
# 3  JONES   MANAGER

# %%
emp.columns
# Out:
# Index(['EMPNO', 'ENAME', 'JOB', 'MGR', 'HIREDATE', 'SAL', 'COMM', 'DEPTNO'], dtype='object')

# %%
# 'S'로 시작하는 컬럼만 뽑기
target = emp.filter(regex='^S').columns.tolist()
target
# Out:
# ['SAL']

# %%
target = emp.filter(regex='^E')
target
# Out:
#     EMPNO   ENAME
# 0    7369   SMITH
# 1    7499   ALLEN
# 2    7521    WARD
# 3    7566   JONES
# 4    7654  MARTIN
# 5    7698   BLAKE
# 6    7782   CLARK
# 7    7788   SCOTT
# 8    7839    KING
# 9    7844  TURNER
# 10   7876   ADAMS
# 11   7900   JAMES
# 12   7902    FORD
# 13   7934  MILLER

# %%
    emp.loc[:,list(emp.columns[3:5])+[emp.columns[7]]]
# Out:
#        MGR             HIREDATE DEPTNO
# 0   7902.0  1980-12-17 00:00:00     20
# 1   7698.0  1981-02-20 00:00:00     30
# 2   7698.0  1981-02-22 00:00:00     30
# 3   7839.0  1981-04-02 00:00:00     20
# 4   7698.0  1981-09-28 00:00:00     30
# 5   7839.0  1981-05-01 00:00:00     30
# 6   7839.0  1981-06-09 00:00:00     10
# 7   7566.0  1987-07-13 00:00:00     20
# 8      NaN  1981-11-17 00:00:00     10
# 9   7698.0  1981-09-08 00:00:00     30
# 10  7788.0  1987-07-13 00:00:00     20
# 11  7698.0  1981-12-03 00:00:00     30
# 12  7566.0  1981-12-03 00:00:00     20
# 13  7782.0  1982-01-23 00:00:00     10

# %%
a = len(emp.columns.tolist())

# %%
emp.iloc[:,[len(emp.columns)-1]]
# Out:
#    DEPTNO
# 0      20
# 1      30
# 2      30
# 3      20
# 4      30
# 5      30
# 6      10
# 7      20
# 8      10
# 9      30
# 10     20
# 11     30
# 12     20
# 13     10

# %%
emp.iloc[[-1, -2],:]
# Out:
#     EMPNO   ENAME      JOB     MGR             HIREDATE   SAL  COMM DEPTNO
# 13   7934  MILLER    CLERK  7782.0  1982-01-23 00:00:00  1300   NaN     10
# 12   7902    FORD  ANALYST  7566.0  1981-12-03 00:00:00  3000   NaN     20

# %%
emp.loc[emp['ENAME']=='FORD','DEPTNO']
# Out:
# 12    20
# Name: DEPTNO, dtype: category
# Categories (3, int64): [10, 20, 30]

# %%
empcopy = emp.copy()

# %%
empcopy.loc[0:2,['ENAME','SAL']]
# Out:
#    ENAME   SAL
# 0  SMITH   800
# 1  ALLEN  1600
# 2   WARD  1250

# %%
empcopy.loc[0:2,['SAL']] = 10

# %%
empcopy.loc[0:2,['ENAME','SAL']]
# Out:
#    ENAME  SAL
# 0  SMITH   10
# 1  ALLEN   10
# 2   WARD   10

# %%
empcopy.loc[0:2,['JOB','SAL']] = ['AAA',50]

# %%
empcopy.loc[0:2,['JOB','SAL']]
# Out:
#    JOB  SAL
# 0  AAA   50
# 1  AAA   50
# 2  AAA   50

# %%
empcopy.loc[empcopy['JOB']=='CLERK','SAL']
# Out:
# 10    1100
# 11     950
# 13    1300
# Name: SAL, dtype: int64

# %%
empcopy.loc[empcopy['JOB']=='CLERK','SAL'] = 11

# %%
empcopy.loc[empcopy['JOB']=='CLERK','SAL']
# Out:
# 10    11
# 11    11
# 13    11
# Name: SAL, dtype: int64

# %%
empcopy.head()
# Out:
#    EMPNO   ENAME       JOB     MGR             HIREDATE   SAL    COMM DEPTNO
# 0   7369   SMITH       AAA  7902.0  1980-12-17 00:00:00    50     NaN     20
# 1   7499   ALLEN       AAA  7698.0  1981-02-20 00:00:00    50   300.0     30
# 2   7521    WARD       AAA  7698.0  1981-02-22 00:00:00    50   500.0     30
# 3   7566   JONES   MANAGER  7839.0  1981-04-02 00:00:00  2975     NaN     20
# 4   7654  MARTIN  SALESMAN  7698.0  1981-09-28 00:00:00  1250  1400.0     30

# %%
empcopy['DEPTNO']
# Out:
# 0     20
# 1     30
# 2     30
# 3     20
# 4     30
# 5     30
# 6     10
# 7     20
# 8     10
# 9     30
# 10    20
# 11    30
# 12    20
# 13    10
# Name: DEPTNO, dtype: category
# Categories (3, int64): [10, 20, 30]

# %%
empcopy['DEPTNO'] = empcopy['DEPTNO'].astype('int')+1

# %%
empcopy['DEPTNO']
# Out:
# 0     21
# 1     31
# 2     31
# 3     21
# 4     31
# 5     31
# 6     11
# 7     21
# 8     11
# 9     31
# 10    21
# 11    31
# 12    21
# 13    11
# Name: DEPTNO, dtype: int64

# %%
empcopy['DEPTNO'] += 1

# %%
empcopy.loc[:10,'DEPTNO'] = empcopy['DEPTNO'] +1

# %%
empcopy['DEPTNO']
# Out:
# 0     23
# 1     33
# 2     33
# 3     23
# 4     33
# 5     33
# 6     13
# 7     23
# 8     13
# 9     33
# 10    23
# 11    32
# 12    22
# 13    12
# Name: DEPTNO, dtype: int64

# %%
empcopy['DEPTNO'] = emp['DEPTNO']

# %%
empcopy['DEPTNO']
# Out:
# 0     20
# 1     30
# 2     30
# 3     20
# 4     30
# 5     30
# 6     10
# 7     20
# 8     10
# 9     30
# 10    20
# 11    30
# 12    20
# 13    10
# Name: DEPTNO, dtype: category
# Categories (3, int64): [10, 20, 30]

# %%
emp.head()
# Out:
#    EMPNO   ENAME       JOB     MGR             HIREDATE   SAL    COMM DEPTNO
# 0   7369   SMITH     CLERK  7902.0  1980-12-17 00:00:00   800     NaN     20
# 1   7499   ALLEN  SALESMAN  7698.0  1981-02-20 00:00:00  1600   300.0     30
# 2   7521    WARD  SALESMAN  7698.0  1981-02-22 00:00:00  1250   500.0     30
# 3   7566   JONES   MANAGER  7839.0  1981-04-02 00:00:00  2975     NaN     20
# 4   7654  MARTIN  SALESMAN  7698.0  1981-09-28 00:00:00  1250  1400.0     30

# %% [markdown]
# <pre><font color=red><b>
# emp ['컬럼']                emp.loc[ : ,  '컬럼'           ]
# emp [['컬럼1', '컬럼2']]    emp.loc[ : ,  ['컬럼1', '컬럼2'] ]
#
#
# emp.loc[  emp['컬럼']=='CLERK'    ,  '컬럼2']
#          |- - - -조건절- - -|
#
# emp[['컬럼1', '컬럼2']] [조건절]
# emp[조건절][['컬럼1', '컬럼2']]

# %%
emp[emp['SAL']>=3000][['ENAME', 'SAL']]
# Out:
#     ENAME   SAL
# 7   SCOTT  3000
# 8    KING  5000
# 12   FORD  3000

# %%
emp.loc[emp['SAL']>=3000,['ENAME', 'SAL']]
# Out:
#     ENAME   SAL
# 7   SCOTT  3000
# 8    KING  5000
# 12   FORD  3000

# %%
emp[(emp['SAL']>=3000) & (emp['JOB']=='ANALYST')][['ENAME', 'SAL', 'JOB']]
# Out:
#     ENAME   SAL      JOB
# 7   SCOTT  3000  ANALYST
# 12   FORD  3000  ANALYST

# %%
emp.loc[(emp['SAL']>=3000) & (emp['JOB']=='ANALYST'),['ENAME', 'SAL', 'JOB']]
# Out:
#     ENAME   SAL      JOB
# 7   SCOTT  3000  ANALYST
# 12   FORD  3000  ANALYST

# %%
emp[['ENAME', 'DEPTNO']][(emp['DEPTNO']==10)|(emp['DEPTNO']==20)]
# Out:
#      ENAME DEPTNO
# 0    SMITH     20
# 3    JONES     20
# 6    CLARK     10
# 7    SCOTT     20
# 8     KING     10
# 10   ADAMS     20
# 12    FORD     20
# 13  MILLER     10

# %%
emp.loc[(emp['DEPTNO']==10)|(emp['DEPTNO']==20),['ENAME', 'DEPTNO']]
# Out:
#      ENAME DEPTNO
# 0    SMITH     20
# 3    JONES     20
# 6    CLARK     10
# 7    SCOTT     20
# 8     KING     10
# 10   ADAMS     20
# 12    FORD     20
# 13  MILLER     10

# %%
emp.loc[(emp['DEPTNO'].isin([10, 20])) ,['ENAME', 'DEPTNO']]
# Out:
#      ENAME DEPTNO
# 0    SMITH     20
# 3    JONES     20
# 6    CLARK     10
# 7    SCOTT     20
# 8     KING     10
# 10   ADAMS     20
# 12    FORD     20
# 13  MILLER     10

# %%
empcopy.loc[(empcopy['DEPTNO'].isin([10, 20])) ,['SAL']] = 10

# %%
empcopy.loc[(empcopy['DEPTNO'].isin([10, 20])) ,['SAL']]
# Out:
#     SAL
# 0    10
# 3    10
# 6    10
# 7    10
# 8    10
# 10   10
# 12   10
# 13   10

# %%
empcopy['new_column'] = 0

# %%
empcopy.head()
# Out:
#    EMPNO   ENAME       JOB     MGR             HIREDATE   SAL    COMM DEPTNO  \
# 0   7369   SMITH       AAA  7902.0  1980-12-17 00:00:00    10     NaN     20
# 1   7499   ALLEN       AAA  7698.0  1981-02-20 00:00:00    50   300.0     30
# 2   7521    WARD       AAA  7698.0  1981-02-22 00:00:00    50   500.0     30
# 3   7566   JONES   MANAGER  7839.0  1981-04-02 00:00:00    10     NaN     20
# 4   7654  MARTIN  SALESMAN  7698.0  1981-09-28 00:00:00  1250  1400.0     30
#
#    new_column
# 0           0
# 1           0
# 2           0
# 3           0
# 4           0

# %%
empcopy.loc[emp['DEPTNO'] == 10 , 'new_column2'] = '부서10'

# %%
empcopy.head()
# Out:
#    EMPNO   ENAME       JOB     MGR             HIREDATE   SAL    COMM DEPTNO  \
# 0   7369   SMITH       AAA  7902.0  1980-12-17 00:00:00    10     NaN     20
# 1   7499   ALLEN       AAA  7698.0  1981-02-20 00:00:00    50   300.0     30
# 2   7521    WARD       AAA  7698.0  1981-02-22 00:00:00    50   500.0     30
# 3   7566   JONES   MANAGER  7839.0  1981-04-02 00:00:00    10     NaN     20
# 4   7654  MARTIN  SALESMAN  7698.0  1981-09-28 00:00:00  1250  1400.0     30
#
#    new_column new_column2
# 0           0         NaN
# 1           0         NaN
# 2           0         NaN
# 3           0         NaN
# 4           0         NaN

# %%
empcopy.loc[emp['DEPTNO'] == 10 , :]
# Out:
#     EMPNO   ENAME        JOB     MGR             HIREDATE  SAL  COMM DEPTNO  \
# 6    7782   CLARK    MANAGER  7839.0  1981-06-09 00:00:00   10   NaN     10
# 8    7839    KING  PRESIDENT     NaN  1981-11-17 00:00:00   10   NaN     10
# 13   7934  MILLER      CLERK  7782.0  1982-01-23 00:00:00   10   NaN     10
#
#     new_column new_column2
# 6            0        부서10
# 8            0        부서10
# 13           0        부서10

# %%
empcopy = emp.copy()


empcopy.loc[empcopy.isna().any(axis=1),:]
# Out:
#     EMPNO   ENAME        JOB     MGR             HIREDATE   SAL  COMM DEPTNO
# 0    7369   SMITH      CLERK  7902.0  1980-12-17 00:00:00   800   NaN     20
# 3    7566   JONES    MANAGER  7839.0  1981-04-02 00:00:00  2975   NaN     20
# 5    7698   BLAKE    MANAGER  7839.0  1981-05-01 00:00:00  2850   NaN     30
# 6    7782   CLARK    MANAGER  7839.0  1981-06-09 00:00:00  2450   NaN     10
# 7    7788   SCOTT    ANALYST  7566.0  1987-07-13 00:00:00  3000   NaN     20
# 8    7839    KING  PRESIDENT     NaN  1981-11-17 00:00:00  5000   NaN     10
# 10   7876   ADAMS      CLERK  7788.0  1987-07-13 00:00:00  1100   NaN     20
# 11   7900   JAMES      CLERK  7698.0  1981-12-03 00:00:00   950   NaN     30
# 12   7902    FORD    ANALYST  7566.0  1981-12-03 00:00:00  3000   NaN     20
# 13   7934  MILLER      CLERK  7782.0  1982-01-23 00:00:00  1300   NaN     10

# %%
None
pd.NA

# %%
df = pd.DataFrame( {
 "name" : ["김길동", "홍길동", "아무개", None],
  "age" : [10, 20,None, None    ],
  "sal" : [1000,None,3000,4000],
  "deptno" : [10,10,10,20]    
})

# %%
df
# Out:
#    name   age     sal  deptno
# 0   김길동  10.0  1000.0      10
# 1   홍길동  20.0     NaN      10
# 2   아무개   NaN  3000.0      10
# 3  None   NaN  4000.0      20

# %%
dfcp = df.copy()

# %%
dfcp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   name    3 non-null      object
#  1   age     2 non-null      float64
#  2   sal     3 non-null      float64
#  3   deptno  4 non-null      int64
# dtypes: float64(2), int64(1), object(1)
# memory usage: 256.0+ bytes

# %%
dfcp.fillna(0)
# Out:
#   name   age     sal  deptno
# 0  김길동  10.0  1000.0      10
# 1  홍길동  20.0     0.0      10
# 2  아무개   0.0  3000.0      10
# 3    0   0.0  4000.0      20

# %%
dfcp = df.copy()

# %%
dfcp['sal'] = dfcp['sal'].fillna(999)

# %%
dfcp
# Out:
#    name   age     sal  deptno
# 0   김길동  10.0  1000.0      10
# 1   홍길동  20.0   999.0      10
# 2   아무개   NaN  3000.0      10
# 3  None   NaN  4000.0      20

# %%
dfcp = df.copy()

# %%
dfcp['sal'].fillna(999, inplace=True)
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_3760\1770719581.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   dfcp['sal'].fillna(999, inplace=True)

# %%
dfcp.fillna({'sal':999}, inplace=True)

# %%
dfcp
# Out:
#    name   age     sal  deptno
# 0   김길동  10.0  1000.0      10
# 1   홍길동  20.0   999.0      10
# 2   아무개   NaN  3000.0      10
# 3  None   NaN  4000.0      20

# %%
dfcp = df.copy()

# %%
dfcp.fillna({'sal':999, 'age':10, 'name':'공백'}, inplace=True)
dfcp
# Out:
#   name   age     sal  deptno
# 0  김길동  10.0  1000.0      10
# 1  홍길동  20.0   999.0      10
# 2  아무개  10.0  3000.0      10
# 3   공백  10.0  4000.0      20

# %%
dfcp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   name    4 non-null      object
#  1   age     4 non-null      float64
#  2   sal     4 non-null      float64
#  3   deptno  4 non-null      int64
# dtypes: float64(2), int64(1), object(1)
# memory usage: 256.0+ bytes

# %%
dfcp = df.copy()

# %%
df.loc[1,'name'] = '김길동'
df
# Out:
#    name   age     sal  deptno
# 0   김길동  10.0  1000.0      10
# 1   김길동  20.0     NaN      10
# 2   아무개   NaN  3000.0      10
# 3  None   NaN  4000.0      20

# %%
dfcp = df.copy()

# %%
dfcp.fillna({'name':dfcp['name'].mode()[0], 
             'age' :dfcp['age'].median() },inplace=True)
dfcp
# Out:
#   name   age     sal  deptno
# 0  김길동  10.0  1000.0      10
# 1  김길동  20.0     NaN      10
# 2  아무개  15.0  3000.0      10
# 3  김길동  15.0  4000.0      20

# %%
dfcp =df.copy()
dfcp['sal'] = dfcp['sal'].ffill()

# %%
dfcp
# Out:
#    name   age     sal  deptno
# 0   김길동  10.0  1000.0      10
# 1   김길동  20.0  1000.0      10
# 2   아무개   NaN  3000.0      10
# 3  None   NaN  4000.0      20

# %%
dfcp =df.copy()
dfcp['sal'] = dfcp['sal'].bfill()

# %%
dfcp
# Out:
#    name   age     sal  deptno
# 0   김길동  10.0  1000.0      10
# 1   김길동  20.0  3000.0      10
# 2   아무개   NaN  3000.0      10
# 3  None   NaN  4000.0      20

# %%
dfcp =df.copy()
dfcp = pd.concat([dfcp, pd.DataFrame([np.nan])])
dfcp
# Out:
#    name   age     sal  deptno   0
# 0   김길동  10.0  1000.0    10.0 NaN
# 1   김길동  20.0     NaN    10.0 NaN
# 2   아무개   NaN  3000.0    10.0 NaN
# 3  None   NaN  4000.0    20.0 NaN
# 0   NaN   NaN     NaN     NaN NaN

# %%
dfcp =df.copy()
dfcp.loc[4,:] = np.nan
dfcp.loc[:,'comm'] = np.nan
dfcp
# Out:
#    name   age     sal  deptno  comm
# 0   김길동  10.0  1000.0    10.0   NaN
# 1   김길동  20.0     NaN    10.0   NaN
# 2   아무개   NaN  3000.0    10.0   NaN
# 3  None   NaN  4000.0    20.0   NaN
# 4   NaN   NaN     NaN     NaN   NaN

# %%
dfcp.dropna(axis=1)
# Out:
# Empty DataFrame
# Columns: []
# Index: [0, 1, 2, 3, 4]

# %%
dfcp.dropna(axis=0)
# Out:
# Empty DataFrame
# Columns: [name, age, sal, deptno, comm]
# Index: []

# %%
emp.groupby('DEPTNO', observed=True).agg(평균급여=('SAL', 'mean'), 인원수=('ENAME', 'count'))
# Out:
#                평균급여  인원수
# DEPTNO
# 10      2916.666667    3
# 20      2175.000000    5
# 30      1566.666667    6

# %%
emp.groupby('DEPTNO', observed=True).agg({'SAL':'mean','ENAME': 'count'})
# Out:
#                 SAL  ENAME
# DEPTNO
# 10      2916.666667      3
# 20      2175.000000      5
# 30      1566.666667      6

# %%
emp.groupby('DEPTNO', observed=True).agg(최대급여 = ('SAL', 'max'),
                                         최소급여 = ('SAL', 'min'),
                                         사원수 = ('ENAME', 'count'))
# Out:
#         최대급여  최소급여  사원수
# DEPTNO
# 10      5000  1300    3
# 20      3000   800    5
# 30      2850   950    6

# %%
dfcp
# Out:
#    name   age     sal  deptno  comm
# 0   김길동  10.0  1000.0    10.0   NaN
# 1   김길동  20.0     NaN    10.0   NaN
# 2   아무개   NaN  3000.0    10.0   NaN
# 3  None   NaN  4000.0    20.0   NaN
# 4   NaN   NaN     NaN     NaN   NaN

# %%
dfcp['sal'].dropna(axis=0)
# Out:
# 0    1000.0
# 2    3000.0
# 3    4000.0
# Name: sal, dtype: float64

# %%
dfcp.dropna(subset=['sal'], axis=0)
# Out:
#    name   age     sal  deptno  comm
# 0   김길동  10.0  1000.0    10.0   NaN
# 2   아무개   NaN  3000.0    10.0   NaN
# 3  None   NaN  4000.0    20.0   NaN

# %%
emp.groupby('DEPTNO', observed=True)['SAL'].mean()
# Out:
# DEPTNO
# 10    2916.666667
# 20    2175.000000
# 30    1566.666667
# Name: SAL, dtype: float64

# %%
df1 = pd.DataFrame([ [1,10]
                   , [2,20]
                  ] , columns=["eno","sal"])
df2 = pd.DataFrame( [['a','aa'] 
                   , ['b','bb']
                  ]  , columns=["c1","c2"])

# %%
df3 = pd.concat([df1, df2])
df3
# Out:
#    eno   sal   c1   c2
# 0  1.0  10.0  NaN  NaN
# 1  2.0  20.0  NaN  NaN
# 0  NaN   NaN    a   aa
# 1  NaN   NaN    b   bb

# %%
df1 = pd.DataFrame([ [1,10]
                   , [2,20]
                  ] , columns=["eno","sal"])
df2 = pd.DataFrame( [['a','aa'] 
                   , ['b','bb']
                  ]  , columns=["eno","sal"])

# %%
df3 = pd.concat([df1, df2], ignore_index = True)
df3
# Out:
#   eno sal
# 0   1  10
# 1   2  20
# 2   a  aa
# 3   b  bb

# %%
df3 = pd.concat([df1, df2]).reset_index()
df3
# Out:
#    index eno sal
# 0      0   1  10
# 1      1   2  20
# 2      0   a  aa
# 3      1   b  bb

# %%
df4 = pd.concat([df1, df2], axis = 1, ignore_index=True)
df4
# Out:
#    0   1  2   3
# 0  1  10  a  aa
# 1  2  20  b  bb

# %%
df4['eno']
# Out:
#   eno eno
# 0   1   a
# 1   2   b

# %%
df1 = pd.DataFrame([ [1,10]
                   , [2,20]
                  ] , columns=["eno","sal"])
df2 = pd.DataFrame( [['a','aa'] 
                   , ['b','bb']
                  ] ,  index = [3, 4], columns=["c1","c2"])

# %%
df4 = pd.concat([df1, df2], axis = 1, ignore_index=True)
df4
# Out:
#      0     1    2    3
# 0  1.0  10.0  NaN  NaN
# 1  2.0  20.0  NaN  NaN
# 3  NaN   NaN    a   aa
# 4  NaN   NaN    b   bb

# %%
df4 = pd.concat([df1.reset_index(), df2.reset_index()], axis = 1, ignore_index=True)
df4
# Out:
#    0  1   2  3  4   5
# 0  0  1  10  3  a  aa
# 1  1  2  20  4  b  bb

# %%
tmp1 = df1.reset_index()
tmp2 = df2.reset_index()
df4 = pd.concat([tmp1, tmp2], axis = 1, ignore_index=True)
df4
# Out:
#    0  1   2  3  4   5
# 0  0  1  10  3  a  aa
# 1  1  2  20  4  b  bb

# %%
tmp1
# Out:
#    index  eno  sal
# 0      0    1   10
# 1      1    2   20

# %%
df1
# Out:
#    eno  sal
# 0    1   10
# 1    2   20

# %%
df1.reset_index()
# Out:
#    index  eno  sal
# 0      0    1   10
# 1      1    2   20

# %%
df1.reset_index()
# Out:
#    index  eno  sal
# 0      0    1   10
# 1      1    2   20

# %%
df5 = df1.reset_index()
df5
# Out:
#    index  eno  sal
# 0      0    1   10
# 1      1    2   20

# %%
df5.shape
# Out:
# (2, 3)

# %%
df6 = df2.reset_index(drop=True)
df6
# Out:
#   c1  c2
# 0  a  aa
# 1  b  bb

# %%
emp
# Out:
#     EMPNO   ENAME        JOB     MGR             HIREDATE   SAL    COMM DEPTNO
# 0    7369   SMITH      CLERK  7902.0  1980-12-17 00:00:00   800     NaN     20
# 1    7499   ALLEN   SALESMAN  7698.0  1981-02-20 00:00:00  1600   300.0     30
# 2    7521    WARD   SALESMAN  7698.0  1981-02-22 00:00:00  1250   500.0     30
# 3    7566   JONES    MANAGER  7839.0  1981-04-02 00:00:00  2975     NaN     20
# 4    7654  MARTIN   SALESMAN  7698.0  1981-09-28 00:00:00  1250  1400.0     30
# 5    7698   BLAKE    MANAGER  7839.0  1981-05-01 00:00:00  2850     NaN     30
# 6    7782   CLARK    MANAGER  7839.0  1981-06-09 00:00:00  2450     NaN     10
# 7    7788   SCOTT    ANALYST  7566.0  1987-07-13 00:00:00  3000     NaN     20
# 8    7839    KING  PRESIDENT     NaN  1981-11-17 00:00:00  5000     NaN     10
# 9    7844  TURNER   SALESMAN  7698.0  1981-09-08 00:00:00  1500     0.0     30
# 10   7876   ADAMS      CLERK  7788.0  1987-07-13 00:00:00  1100     NaN     20
# ...

# %%
# ! pip install duckdb

# %%
import duckdb

# %%
tbl = duckdb.query("select * from emp ").df()

# %%
tbl
# Out:
#     EMPNO   ENAME        JOB     MGR             HIREDATE   SAL    COMM  \
# 0    7369   SMITH      CLERK  7902.0  1980-12-17 00:00:00   800     NaN
# 1    7499   ALLEN   SALESMAN  7698.0  1981-02-20 00:00:00  1600   300.0
# 2    7521    WARD   SALESMAN  7698.0  1981-02-22 00:00:00  1250   500.0
# 3    7566   JONES    MANAGER  7839.0  1981-04-02 00:00:00  2975     NaN
# 4    7654  MARTIN   SALESMAN  7698.0  1981-09-28 00:00:00  1250  1400.0
# 5    7698   BLAKE    MANAGER  7839.0  1981-05-01 00:00:00  2850     NaN
# 6    7782   CLARK    MANAGER  7839.0  1981-06-09 00:00:00  2450     NaN
# 7    7788   SCOTT    ANALYST  7566.0  1987-07-13 00:00:00  3000     NaN
# 8    7839    KING  PRESIDENT     NaN  1981-11-17 00:00:00  5000     NaN
# 9    7844  TURNER   SALESMAN  7698.0  1981-09-08 00:00:00  1500     0.0
# 10   7876   ADAMS      CLERK  7788.0  1987-07-13 00:00:00  1100     NaN
# 11   7900   JAMES      CLERK  7698.0  1981-12-03 00:00:00   950     NaN
# ...

# %%
tbl["DEPTNO"]
# Out:
# 0     20
# 1     30
# 2     30
# 3     20
# 4     30
# 5     30
# 6     10
# 7     20
# 8     10
# 9     30
# 10    20
# 11    30
# 12    20
# 13    10
# Name: DEPTNO, dtype: int64

# %%
emp
# Out:
#     EMPNO   ENAME        JOB     MGR             HIREDATE   SAL    COMM DEPTNO
# 0    7369   SMITH      CLERK  7902.0  1980-12-17 00:00:00   800     NaN     20
# 1    7499   ALLEN   SALESMAN  7698.0  1981-02-20 00:00:00  1600   300.0     30
# 2    7521    WARD   SALESMAN  7698.0  1981-02-22 00:00:00  1250   500.0     30
# 3    7566   JONES    MANAGER  7839.0  1981-04-02 00:00:00  2975     NaN     20
# 4    7654  MARTIN   SALESMAN  7698.0  1981-09-28 00:00:00  1250  1400.0     30
# 5    7698   BLAKE    MANAGER  7839.0  1981-05-01 00:00:00  2850     NaN     30
# 6    7782   CLARK    MANAGER  7839.0  1981-06-09 00:00:00  2450     NaN     10
# 7    7788   SCOTT    ANALYST  7566.0  1987-07-13 00:00:00  3000     NaN     20
# 8    7839    KING  PRESIDENT     NaN  1981-11-17 00:00:00  5000     NaN     10
# 9    7844  TURNER   SALESMAN  7698.0  1981-09-08 00:00:00  1500     0.0     30
# 10   7876   ADAMS      CLERK  7788.0  1987-07-13 00:00:00  1100     NaN     20
# ...

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(emp['ENAME'],emp['SAL'])
plt.xlabel("Name")
plt.ylabel("Salary")
plt.title("Open salary")
plt.show()
