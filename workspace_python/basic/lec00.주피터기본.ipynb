# %% [markdown]
# # lec01. 연산

# %% [markdown]
# ## 덧셈

# %% [markdown]
# <font color=red size=6><b>이거 중요

# %% [markdown]
# <img src = "data:image/png;base64,... "
# width=200 height = 100>

# %%
a=100
b=10
a+=b # a = a + b
print(a, b)
# Out:
# 110 10

# %% [markdown]
# ## 뺄셈

# %%
a-=b # a=a-b
print(a, b)
# Out:
# 100 10

# %% [markdown]
# ## 곱셈

# %%
a*=b #a=a*b
print(a, b)
# Out:
# 1000 10

# %% [markdown]
# ## 나눗셈

# %%
a/=b #a=a/b
print(a, b)
# Out:
# 100.0 10

# %% [markdown]
# #### 작은글씨
# - 설명
#     - 설명2
#     - 설명3
# - 설명설명
#     - 설명

# %%
print("hello")
# Out:
# hello

# %%
name = "ABC"
print(name)
# Out:
# ABC

# %%
print(name)
# Out:
# ABC
