# %%
import pandas as pd
import numpy as np
import duckdb
import matplotlib.pyplot as plt
import seaborn as sns
import re
#-------------------- 차트 관련 속성 (한글처리, 그리드) -----------
plt.rcParams['font.family']= 'Malgun Gothic'
plt.rcParams['axes.unicode_minus'] = False
#-------------------- 차트 관련 속성 (차트크기 ) -----------
plt.rcParams['figure.figsize'] = (4, 2)

# %%
train = pd.read_csv('./data/titanic/train.csv')
test = pd.read_csv('./data/titanic/test.csv')
gen = pd.read_csv('./data/titanic/gender_submission.csv')

# %%
train.columns = train.columns.str.lower()
train.columns
# Out:
# Index(['passengerid', 'survived', 'pclass', 'name', 'sex', 'age', 'sibsp',
#        'parch', 'ticket', 'fare', 'cabin', 'embarked'],
#       dtype='object')

# %%
train.head()
# Out:
#    passengerid  survived  pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 name     sex   age  sibsp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    parch            ticket     fare cabin embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   passengerid  891 non-null    int64
#  1   survived     891 non-null    int64
#  2   pclass       891 non-null    int64
#  3   name         891 non-null    object
#  4   sex          891 non-null    object
#  5   age          714 non-null    float64
#  6   sibsp        891 non-null    int64
#  7   parch        891 non-null    int64
#  8   ticket       891 non-null    object
#  9   fare         891 non-null    float64
#  10  cabin        204 non-null    object
#  11  embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
test.head()
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#     Age  SibSp  Parch   Ticket     Fare Cabin Embarked
# 0  34.5      0      0   330911   7.8292   NaN        Q
# 1  47.0      1      0   363272   7.0000   NaN        S
# 2  62.0      0      0   240276   9.6875   NaN        Q
# 3  27.0      0      0   315154   8.6625   NaN        S
# 4  22.0      1      1  3101298  12.2875   NaN        S

# %%
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  418 non-null    int64
#  1   Pclass       418 non-null    int64
#  2   Name         418 non-null    object
#  3   Sex          418 non-null    object
#  4   Age          332 non-null    float64
#  5   SibSp        418 non-null    int64
#  6   Parch        418 non-null    int64
#  7   Ticket       418 non-null    object
#  8   Fare         417 non-null    float64
#  9   Cabin        91 non-null     object
#  10  Embarked     418 non-null    object
# dtypes: float64(2), int64(4), object(5)
# memory usage: 36.0+ KB

# %%
gen.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 2 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  418 non-null    int64
#  1   Survived     418 non-null    int64
# dtypes: int64(2)
# memory usage: 6.7 KB

# %%
train.isna().sum()
# Out:
# passengerid      0
# survived         0
# pclass           0
# name             0
# sex              0
# age            177
# sibsp            0
# parch            0
# ticket           0
# fare             0
# cabin          687
# embarked         2
# dtype: int64

# %%
train.shape
# Out:
# (891, 12)

# %%
train['Survived'].mode()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File C:\IT\workspace_python\.venv\lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3811 try:
# -> 3812     return self._engine.get_loc(casted_key)
#    3813 except KeyError as err:
#
# File pandas/_libs/index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7096, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Survived'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 train['Survived'].mode()
#
# ...

# %%
duckdb.query('''
    select survived, count(survived) as CNT from train group by survived
''')
# Out:
# ┌──────────┬───────┐
# │ survived │  CNT  │
# │  int64   │ int64 │
# ├──────────┼───────┤
# │        1 │   342 │
# │        0 │   549 │
# └──────────┴───────┘

# %%
train.astype('category').groupby(by='survived', observed=True).agg({'survived':'count'})
# Out:
#           survived
# survived
# 0              549
# 1              342

# %%
train['survived'].value_counts()
# Out:
# survived
# 0    549
# 1    342
# Name: count, dtype: int64

# %% [markdown]
# EDA(Exploratory Data Analysis, 탐색적 데이터 분석)
# 시각화, 통계 분석

# %%
train.describe()
# Out:
#        passengerid    survived      pclass         age       sibsp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             parch        fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   passengerid  891 non-null    int64
#  1   survived     891 non-null    int64
#  2   pclass       891 non-null    int64
#  3   name         891 non-null    object
#  4   sex          891 non-null    object
#  5   age          714 non-null    float64
#  6   sibsp        891 non-null    int64
#  7   parch        891 non-null    int64
#  8   ticket       891 non-null    object
#  9   fare         891 non-null    float64
#  10  cabin        204 non-null    object
#  11  embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
train['survived'].value_counts().plot(kind='bar')
plt.show()

# %%
train.loc[train['age'].isna(),:]
# Out:
#      passengerid  survived  pclass                                      name  \
# 5              6         0       3                          Moran, Mr. James
# 17            18         1       2              Williams, Mr. Charles Eugene
# 19            20         1       3                   Masselmani, Mrs. Fatima
# 26            27         0       3                   Emir, Mr. Farred Chehab
# 28            29         1       3             O'Dwyer, Miss. Ellen "Nellie"
# ..           ...       ...     ...                                       ...
# 859          860         0       3                          Razi, Mr. Raihed
# 863          864         0       3         Sage, Miss. Dorothy Edith "Dolly"
# 868          869         0       3               van Melkebeke, Mr. Philemon
# 878          879         0       3                        Laleff, Mr. Kristo
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
#
# ...

# %% [markdown]
# drop : 'passengerid', 'ticket' ....  'cabin'
# 'cabin' : 생존관계 확인 vs. 'survived'  --> drop
# 'embarked' : 생존관계   vs. 'survived'
#                  결측처리(최빈), 인코딩
# 호칭자르기 : 'name'
# 인코딩(글자->숫자) : 'sex' ... 'embarked'
# 바이닝(구간화) : 'age'
# 결측처리 : 'age'(평균...??), 'embarked'(최빈)
# 파생변수(신규변수) : 'family_cnt' = 'sibsp' +  'parch' + 1
# 파생변수(신규변수) : 'fare_rate' = 'fare' / 'family_cnt'

# %%
train.loc[train['cabin'].notna(),'cabin']
# Out:
# 1              C85
# 3             C123
# 6              E46
# 10              G6
# 11            C103
#           ...
# 871            D35
# 872    B51 B53 B55
# 879            C50
# 887            B42
# 889           C148
# Name: cabin, Length: 204, dtype: object

# %%
type(train.loc[872,'cabin']) = 0
# Out:
#   Cell In[20], line 1
#     type(train.loc[872,'cabin']) = 0
#     ^
# SyntaxError: cannot assign to function call here. Maybe you meant '==' instead of '='?

# %%
train['cabin_ox'] = 0
train.loc[train['cabin'].notna(),'cabin_ox'] = 1

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 13 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   passengerid  891 non-null    int64
#  1   survived     891 non-null    int64
#  2   pclass       891 non-null    int64
#  3   name         891 non-null    object
#  4   sex          891 non-null    object
#  5   age          714 non-null    float64
#  6   sibsp        891 non-null    int64
#  7   parch        891 non-null    int64
#  8   ticket       891 non-null    object
#  9   fare         891 non-null    float64
#  10  cabin        204 non-null    object
#  11  embarked     889 non-null    object
#  12  cabin_ox     891 non-null    int64
# dtypes: float64(2), int64(6), object(5)
# memory usage: 90.6+ KB

# %%
train[['cabin_ox', 'survived']].value_counts()
# Out:
# cabin_ox  survived
# 0         0           481
#           1           206
# 1         1           136
#           0            68
# Name: count, dtype: int64

# %%
206/481
# Out:
# 0.4282744282744283

# %%
68/136
# Out:
# 0.5

# %%
train[['embarked','survived', 'passengerid']].groupby(by=['embarked', 'survived']).count().sort_values(['embarked', 'survived'])
# Out:
#                    passengerid
# embarked survived
# C        0                  75
#          1                  93
# Q        0                  47
#          1                  30
# S        0                 427
#          1                 217

# %%
train['embarked'].mode()[0]
# Out:
# 'S'

# %%
train['embarked'].fillna(train['embarked'].mode()[0], inplace=True)
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_5440\2866719905.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   train['embarked'].fillna(train['embarked'].mode()[0], inplace=True)

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 13 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   passengerid  891 non-null    int64
#  1   survived     891 non-null    int64
#  2   pclass       891 non-null    int64
#  3   name         891 non-null    object
#  4   sex          891 non-null    object
#  5   age          714 non-null    float64
#  6   sibsp        891 non-null    int64
#  7   parch        891 non-null    int64
#  8   ticket       891 non-null    object
#  9   fare         891 non-null    float64
#  10  cabin        204 non-null    object
#  11  embarked     891 non-null    object
#  12  cabin_ox     891 non-null    int64
# dtypes: float64(2), int64(6), object(5)
# memory usage: 90.6+ KB

# %%
tcp = train.copy()

# %%
tcp['embarked'] = tcp['embarked'].replace({'S':0, 'C':1, 'Q':2})
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_5440\126682182.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   tcp['embarked'] = tcp['embarked'].replace({'S':0, 'C':1, 'Q':2})

# %%
tcp.head()
# Out:
#    passengerid  survived  pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 name     sex   age  sibsp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    parch            ticket     fare cabin  embarked  cabin_ox
# 0      0         A/5 21171   7.2500   NaN         0         0
# 1      0          PC 17599  71.2833   C85         1         1
# 2      0  STON/O2. 3101282   7.9250   NaN         0         0
# 3      0            113803  53.1000  C123         0         1
# ...

# %%
tcp = train.copy()
tcp.head(2)
# Out:
#    passengerid  survived  pclass  \
# 0            1         0       3
# 1            2         1       1
#
#                                                 name     sex   age  sibsp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
#
#    parch     ticket     fare cabin embarked  cabin_ox
# 0      0  A/5 21171   7.2500   NaN        S         0
# 1      0   PC 17599  71.2833   C85        C         1

# %%
tcp['embarked'] = tcp['embarked'].map({'S':0, 'C':1, 'Q':2})
tcp.head(2)
# Out:
#    passengerid  survived  pclass  \
# 0            1         0       3
# 1            2         1       1
#
#                                                 name     sex   age  sibsp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
#
#    parch     ticket     fare cabin  embarked  cabin_ox
# 0      0  A/5 21171   7.2500   NaN         0         0
# 1      0   PC 17599  71.2833   C85         1         1

# %%
tcp = train.copy()
tcp.head(2)
# Out:
#    passengerid  survived  pclass  \
# 0            1         0       3
# 1            2         1       1
#
#                                                 name     sex   age  sibsp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
#
#    parch     ticket     fare cabin embarked  cabin_ox
# 0      0  A/5 21171   7.2500   NaN        S         0
# 1      0   PC 17599  71.2833   C85        C         1

# %%
# ! pip show scikit-learn
# Out:
# Name: scikit-learn
# Version: 1.7.2
# Summary: A set of python modules for machine learning and data mining
# Home-page: https://scikit-learn.org
# Author:
# Author-email:
# License-Expression: BSD-3-Clause
# Location: c:\it\workspace_python\.venv\lib\site-packages
# Requires: joblib, numpy, scipy, threadpoolctl
# Required-by:

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()

# %%
le.fit(tcp['embarked'])
le.classes_
# Out:
# array(['C', 'Q', 'S'], dtype=object)

# %%
res = le.transform(tcp['embarked'])
res
# Out:
# array([2, 0, 2, 2, 2, 1, 2, 2, 2, 0, 2, 2, 2, 2, 2, 2, 1, 2, 2, 0, 2, 2,
#        1, 2, 2, 2, 0, 2, 1, 2, 0, 0, 1, 2, 0, 2, 0, 2, 2, 0, 2, 2, 0, 0,
#        1, 2, 1, 1, 0, 2, 2, 2, 0, 2, 0, 2, 2, 0, 2, 2, 0, 2, 2, 2, 0, 0,
#        2, 2, 2, 2, 2, 2, 2, 0, 2, 2, 2, 2, 2, 2, 2, 2, 1, 2, 2, 2, 2, 2,
#        2, 2, 2, 2, 2, 2, 2, 2, 0, 0, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 1,
#        2, 0, 2, 2, 0, 2, 1, 2, 0, 2, 2, 2, 0, 2, 2, 0, 1, 2, 0, 2, 0, 2,
#        2, 2, 2, 0, 2, 2, 2, 0, 0, 2, 2, 1, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2,
#        2, 0, 1, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 1, 2, 2, 0, 2,
#        2, 0, 2, 2, 2, 0, 2, 2, 2, 2, 1, 2, 1, 2, 2, 2, 2, 2, 0, 0, 1, 2,
#        1, 2, 2, 2, 2, 0, 2, 2, 2, 0, 1, 0, 2, 2, 2, 2, 1, 0, 2, 2, 0, 2,
#        2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 0, 1,
#        2, 2, 0, 1, 2, 2, 2, 2, 2, 2, 2, 2, 2, 0, 0, 2, 0, 2, 1, 2, 2, 2,
#        1, 2, 2, 2, 2, 2, 2, 2, 2, 0, 1, 2, 2, 2, 1, 2, 1, 2, 2, 2, 2, 0,
# ...

# %%
le.inverse_transform(res)
# Out:
# array(['S', 'C', 'S', 'S', 'S', 'Q', 'S', 'S', 'S', 'C', 'S', 'S', 'S',
#        'S', 'S', 'S', 'Q', 'S', 'S', 'C', 'S', 'S', 'Q', 'S', 'S', 'S',
#        'C', 'S', 'Q', 'S', 'C', 'C', 'Q', 'S', 'C', 'S', 'C', 'S', 'S',
#        'C', 'S', 'S', 'C', 'C', 'Q', 'S', 'Q', 'Q', 'C', 'S', 'S', 'S',
#        'C', 'S', 'C', 'S', 'S', 'C', 'S', 'S', 'C', 'S', 'S', 'S', 'C',
#        'C', 'S', 'S', 'S', 'S', 'S', 'S', 'S', 'C', 'S', 'S', 'S', 'S',
#        'S', 'S', 'S', 'S', 'Q', 'S', 'S', 'S', 'S', 'S', 'S', 'S', 'S',
#        'S', 'S', 'S', 'S', 'S', 'C', 'C', 'S', 'S', 'S', 'S', 'S', 'S',
#        'S', 'S', 'S', 'S', 'S', 'Q', 'S', 'C', 'S', 'S', 'C', 'S', 'Q',
#        'S', 'C', 'S', 'S', 'S', 'C', 'S', 'S', 'C', 'Q', 'S', 'C', 'S',
#        'C', 'S', 'S', 'S', 'S', 'C', 'S', 'S', 'S', 'C', 'C', 'S', 'S',
#        'Q', 'S', 'S', 'S', 'S', 'S', 'S', 'S', 'S', 'S', 'S', 'S', 'C',
#        'Q', 'S', 'S', 'S', 'S', 'S', 'S', 'S', 'S', 'S', 'S', 'S', 'S',
# ...

# %%
res = le.transform(tcp['embarked'])
tcp['embarked'] = res
tcp.head()
# Out:
#    passengerid  survived  pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 name     sex   age  sibsp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    parch            ticket     fare cabin  embarked  cabin_ox
# 0      0         A/5 21171   7.2500   NaN         2         0
# 1      0          PC 17599  71.2833   C85         0         1
# 2      0  STON/O2. 3101282   7.9250   NaN         2         0
# 3      0            113803  53.1000  C123         2         1
# ...

# %%
tcp = train.copy()
tcp.head(2)
# Out:
#    passengerid  survived  pclass  \
# 0            1         0       3
# 1            2         1       1
#
#                                                 name     sex   age  sibsp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
#
#    parch     ticket     fare cabin embarked  cabin_ox
# 0      0  A/5 21171   7.2500   NaN        S         0
# 1      0   PC 17599  71.2833   C85        C         1

# %%
tcp['embarked'] = tcp['embarked'].astype('category')
tcp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 13 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   passengerid  891 non-null    int64
#  1   survived     891 non-null    int64
#  2   pclass       891 non-null    int64
#  3   name         891 non-null    object
#  4   sex          891 non-null    object
#  5   age          714 non-null    float64
#  6   sibsp        891 non-null    int64
#  7   parch        891 non-null    int64
#  8   ticket       891 non-null    object
#  9   fare         891 non-null    float64
#  10  cabin        204 non-null    object
#  11  embarked     891 non-null    category
#  12  cabin_ox     891 non-null    int64
# dtypes: category(1), float64(2), int64(6), object(4)
# memory usage: 84.7+ KB

# %%
tcp['embarked'].cat.codes
# Out:
# 0      2
# 1      0
# 2      2
# 3      2
# 4      2
#       ..
# 886    2
# 887    2
# 888    2
# 889    0
# 890    1
# Length: 891, dtype: int8

# %%
tcp = train.copy()
tcp.head(2)
# Out:
#    passengerid  survived  pclass  \
# 0            1         0       3
# 1            2         1       1
#
#                                                 name     sex   age  sibsp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
#
#    parch     ticket     fare cabin embarked  cabin_ox
# 0      0  A/5 21171   7.2500   NaN        S         0
# 1      0   PC 17599  71.2833   C85        C         1

# %%
mymap=dict(zip(tcp['embarked'].unique(), np.arange(0,len(tcp['embarked'].unique()))))
mymap
# Out:
# {'S': np.int64(0), 'C': np.int64(1), 'Q': np.int64(2)}

# %%
tcp['embarked'] = tcp['embarked'].map(mymap)
tcp.head()
# Out:
#    passengerid  survived  pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 name     sex   age  sibsp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    parch            ticket     fare cabin  embarked  cabin_ox
# 0      0         A/5 21171   7.2500   NaN         0         0
# 1      0          PC 17599  71.2833   C85         1         1
# 2      0  STON/O2. 3101282   7.9250   NaN         0         0
# 3      0            113803  53.1000  C123         0         1
# ...

# %%
tcp['embarked'].unique()
# Out:
# array([0, 1, 2])

# %%
plt.figure(figsize=(4,2))
plt.hist(train['age'])
plt.show()

# %%
plt.figure(figsize=(4,2))
train['age'].plot(kind='bar')
plt.show()

# %%
#-------------------- 주피터 , 출력결과 넓이 늘리기 ---------------
# from IPython.core.display import display, HTML
from IPython.display import display, HTML
display(HTML("<style>.container{width:100% !important;}</style>"))
pd.set_option('display.max_rows', 100)
pd.set_option('display.max_columns', 100)
pd.set_option('max_colwidth', None)
# Out:
# <style>.container{width:100% !important;}</style>

# %%
plt.figure(figsize=(6,2))
train['age'].plot(kind='hist', bins=19)
plt.xticks(range(0, 80, 5))
plt.title("히스토그램")
plt.show()

# %%
# ! pip install seaborn

# %%
sns.histplot(train,x='age')
plt.show()

# %%
sns.displot(train, x='age', col = 'pclass', row='sex')
plt.title('distplot')
plt.show()

# %%
g = sns.displot(
    train,
    x="age",
    col="pclass",
    row="sex",
    height=3,
    aspect=1
)

g.fig.suptitle(
    "Age Distribution by Class and Sex",
    fontsize=16,
    fontweight="bold",
    y=1.05
)

g.fig.subplots_adjust(top=0.85)
plt.show()

# %%
sns.displot(train, x='age', aspect=4)
plt.title('distplot')
plt.gcf().set_size_inches(14, 3)
plt.show()

# %%
sns.displot(train, x='age', kde=True)
plt.title('distplot')
plt.gcf().set_size_inches(14, 3)
plt.show()

# %%
train.hist()
plt.gcf().set_size_inches(14, 5)
plt.tight_layout()
plt.show()

# %% [markdown]
# <font size=4 color=red><b>train['컬럼'].str.extract("(정규표현식)")

# %%
train['name'].str.extract(', ([a-zA-Z ]*)[.]')
# Out:
#         0
# 0      Mr
# 1     Mrs
# 2    Miss
# 3     Mrs
# 4      Mr
# ..    ...
# 886   Rev
# 887  Miss
# 888  Miss
# 889    Mr
# 890    Mr
#
# [891 rows x 1 columns]

# %%
train['name'].str.extract(', ([a-zA-Z ]*)[.]', expand=False).unique()
# Out:
# array(['Mr', 'Mrs', 'Miss', 'Master', 'Don', 'Rev', 'Dr', 'Mme', 'Ms',
#        'Major', 'Lady', 'Sir', 'Mlle', 'Col', 'Capt', 'the Countess',
#        'Jonkheer'], dtype=object)

# %%
train['name'].str.extract(', ([A-Za-z]+)\.')
# Out:
#         0
# 0      Mr
# 1     Mrs
# 2    Miss
# 3     Mrs
# 4      Mr
# ..    ...
# 886   Rev
# 887  Miss
# 888  Miss
# 889    Mr
# 890    Mr
#
# [891 rows x 1 columns]
