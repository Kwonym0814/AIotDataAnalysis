# %% [markdown]
# *: key arg.
#
# **: key dic.

# %%
def myprint(num,*args):
    print(args)

# %%
myprint(10)
# Out:
# (10,)

# %%
myprint(num=4, 1,2)
# Out:
#   Cell In[14], line 1
#     myprint(num=4, 1,2)
#                       ^
# SyntaxError: positional argument follows keyword argument
