# %% [markdown]
# lec02. 조건문 & 반복문

# %% [markdown]
# 조건문
# <pre>
# if (조건문A):
#     ______  <= 출력/연산/대입
# elif (조건B):
#     _______
# else :
#     _______
#
#
# 중첩 조건문
# if (조건문A):
#     if (조건문A):
#         ______  <= 출력/연산/대입
#     elif (조건B):
#         _______
#     else :
#         _______
# elif (조건B):
#     if (조건문A):
#         ______  <= 출력/연산/대입
#     elif (조건B):
#         _______
#     else :
#         _______
# else :
#     if (조건문A):
#         ______  <= 출력/연산/대입
#     elif (조건B):
#         _______
#     else :
#         _______
#
# </pre>

# %%
score = 70

# %%
if score >= 90:
    print('a')
else:
    print('b')
# Out:
# b

# %%
if score >= 90:
    res = "a"
else:
    res = "b"

print(res)
# Out:
# b

# %%
gen = "남성"

# %%
if gen == "남성" :
    print("군필")
else:
    print("면제")
# Out:
# 군필

# %%
if gen == "남성" :
    army_ass = "군필"
else:
    army_ass = "면제"

print(army_ass)
# Out:
# 군필

# %%
# 20대, 남성: 군필
# 면제
age = 47
gen = "남성"

# %%
if (20 <= age < 30) and gen == "남성":
    print("군필")
else:
    print("면제")
# Out:
# 면제

# %%
if (20 <= age < 30) and gen == "남성":
    army_ass = "군필"
else:
    army_ass = "면제"

print(army_ass)
# Out:
# 면제

# %%
age = 47
gen = "남성"

# %%
if gen == "남성":
    if age >= 20 and age < 30 :
    #if age // 10 == 2 :
        print("군필")
    else:
        print("면제")
else:
    print("면제")
# Out:
# 면제

# %%
num = 9

# %%
if num % 2 == 0:
    pirnt("짝")
else:
    print("홀")
# Out:
# 홀
