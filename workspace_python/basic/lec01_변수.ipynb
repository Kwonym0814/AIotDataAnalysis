# %% [markdown]
# 오늘의 수업
# 1. 파이썬
#    -변수
#    -연산자, 타입, 캐스팅
#    -if 조건문
#    -for, while 반복문
#    -변수+반복 -> 리스트, 튜플, 딕셔너리 ::: 가장 중요
#
# 아마도 월요일
# 2. 데이터 저장:: json - 딕셔너리, REST, API
#  양이 많을 경우 : file: TB~ : SPARK(유료-시간당 300~500기가), 하둡(무료 - 1000 엑사이상) - docker병렬할 때
#  그렇지 않을 경우 : DB: RBD(RBD: 오라클, mysql  ;VECDB: Pinecone(유료), FAISS(무료) -RAG할 때, ;INMDB: Redis-스트리밍서비스) -> 최대 2기가 이내
#                         NoSQL -> 몽고, HBASE -> docker병렬할 때
#
# 3. 머신러닝
#     - 전처리 : dataframe으로 전처리:
#
# 4. 딥러닝
#     - CNN(이미지분석)
#     - RNN(언어모델) - LLM: 거대언어모델
#                     - TS: 시간
#
# 5. AX: 업무 자동화 (여기 윗 단계는 AI)
#  - LAG
#  - 랭체인
#  - 에이전트
#
#
#
# * 데이콘, 캐글

# %% [markdown]
# <font size = 6> lec01 변수

# %% [markdown]
#  * 값을 담는 그릇(저장공간)
#  * 메모리 공간
#  * 주소표기: 4바이트(32bit) 16진법(0,1,2,...,A,B,C,D,...,E,F)
#      - 1 비트: 0 또는 1 바이너리.
#      - 8비트 = 1바이트
#      - 예: 0x123FB
#  * 데이터는 주소에 저장되지만 주소는 사람이 쓰기 불편하므로 주소를 대신 변수를 쓴다.
#
#
# 글자표현, int: 4바이트
# 실수: 8바이트

# %% [markdown]
# 타입

# %% [markdown]
# 정수: int
# 실수: float, double
# 글자: str
# 불리언: True/False
# 날짜: Date(import)

# %% [raw]
# 연산

# %% [raw]
# 가감산: +, -, *, /, %(나머지), //(몫)
# 우선순위: 괄호, 곱하기, 더하기
# 연산 시 캐스팅 발생(연산 중 타입이 변환되는 것):
