# %%
numbers = []

# %%
def solution() :
    numbers1 = []
    numbers2 = []
    numbers3 = []
    for num in numbers:
        if num > 0 :
            numbers1.append(num)
        elif num == 0 :
            numbers2.append(num)
        elif num < 0 :
            numbers3.append(num)
    if len(numbers1) > 2:
        if len(numbers3)>2:
            a,b = numbers1.sort(revers=True)[0], numbers1.sort(revers=True)[1]
            c,d = numbers3.sort()[0], numbers3.sort()[1]
            return max(a*b, c*d)
        else:
            a,b = numbers1.sort(revers=True)[0], numbers1.sort(revers=True)[1]
            return a*b
    elif len(numbers1) == 1:
        if len(numbers3)>2:
            c,d = numbers3.sort()[0], numbers3.sort()[1]
            return c*d
        elif len(numbers3) == 1:

# %%
def solution(numbers) :
    tmp = []
    for i in range(0,len(numbers)):
        for j in range(0,len(numbers)):
            if i == j :
                pass
            elif i < j:
                pass
            else :
                tmp.append(numbers[i]*numbers[j])
    return max(tmp)

# %%
numbers = [1, 2,-3,4,-5]
solution(numbers)
# Out:
# 15

# %%
numbers = [0, -31, 24, 10, 1, 9]
solution(numbers)
# Out:
# 240

# %%
numbers = [10, 20, 30, 5, 5, 20, 5]
solution(numbers)
# Out:
# 600

# %%
code,
cypher

# %%
def solution1(cypher, code):
    num = len(cypher) // code 
    str = []
    for i in range(code,code*num+1,code):
        str.append(cypher[i-1])
    return "".join(str)

# %%
solution1("dfjardstddetckdaccccdegk",4)
# Out:
# 'attack'

# %%
solution1("pfqallllabwaoclk",2)
# Out:
# 'fallback'
