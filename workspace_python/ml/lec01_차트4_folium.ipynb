# %% [markdown]
# # Lec06-4. folium 차트 시각화
# * <b>matplotlib : https://matplotlib.org/stable/
# * <b>seaborn : https://seaborn.pydata.org/
# * <b>plotly : https://plotly.com/python/
# * <b>folium : https://python-visualization.github.io/folium/latest/
# * 연습용 : https://wikidocs.net/92071
# * 연습용 : https://www.kaggle.com/code/barisscal/eda-visualization-with-seaborn

# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px    
import re

import folium                   #------------ foilum 맵
from folium import plugins

import geopandas as gpd         #------------ GeoJSON

import warnings
warnings.filterwarnings(action='ignore')

#-------------------- 차트 관련 속성 (한글처리, 그리드) -----------
plt.rcParams['font.family']= 'Malgun Gothic'
plt.rcParams['axes.unicode_minus'] = False

# %% [markdown]
# # folium 기초

# %%
# 서울시청 : 약 북위 37.56421도, 동경 127.00170도
m = folium.Map(location=(37.56421, 127.00170) , zoom_start=15)
folium.Marker(
    location=[37.56429, 127.00179],
    tooltip="김밥천국",
    popup="<font color=red><img src='https://cdn.informaticsview.com/news/photo/202411/821_3428_620.jpg' width=100 height=100>폰트빨강</font>",
    icon=folium.Icon(icon="cloud"),
).add_to(m)

folium.Marker(
    location=[37.56300, 127.00010],
    tooltip="돈까스전문점",
    popup="010-0101-2152 영업중",
    icon=folium.Icon(color="green"),
).add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_7a60a5987913c5bcd1db7981ab8dcdc1 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_7a60a5987913c5bcd1db7981ab8dcdc1&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_7a60a5987913c5bcd1db7981ab8dcdc1 = L.map(
#                 &quot;map_7a60a5987913c5bcd1db7981ab8dcdc1&quot;,
#                 {
#                     center: [37.56421, 127.0017],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 15,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_d07e6f68bb71791851bea60b092d592b = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_d07e6f68bb71791851bea60b092d592b.addTo(map_7a60a5987913c5bcd1db7981ab8dcdc1);
#
#
#             var marker_0ac324b1b307b661e18864ff77f94939 = L.marker(
#                 [37.56429, 127.00179],
#                 {
# }
#             ).addTo(map_7a60a5987913c5bcd1db7981ab8dcdc1);
#
#
#             var icon_a0f56ccc65301777ac45c2dabd177056 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;blue&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;cloud&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_8d51659222e92ec654f9e30f088f5663 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_58093769a0d3c5748a2f78449cdb9e10 = $(`&lt;div id=&quot;html_58093769a0d3c5748a2f78449cdb9e10&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;font color=red&gt;&lt;img src=&#x27;https://cdn.informaticsview.com/news/photo/202411/821_3428_620.jpg&#x27; width=100 height=100&gt;폰트빨강&lt;/font&gt;&lt;/div&gt;`)[0];
#                 popup_8d51659222e92ec654f9e30f088f5663.setContent(html_58093769a0d3c5748a2f78449cdb9e10);
#
#
#
#         marker_0ac324b1b307b661e18864ff77f94939.bindPopup(popup_8d51659222e92ec654f9e30f088f5663)
#         ;
#
#
#
#
#             marker_0ac324b1b307b661e18864ff77f94939.bindTooltip(
#                 `&lt;div&gt;
#                      김밥천국
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#                 marker_0ac324b1b307b661e18864ff77f94939.setIcon(icon_a0f56ccc65301777ac45c2dabd177056);
#
#
#             var marker_838199e560064c7be54ddea002d52ebf = L.marker(
#                 [37.563, 127.0001],
#                 {
# }
#             ).addTo(map_7a60a5987913c5bcd1db7981ab8dcdc1);
#
#
#             var icon_98e5f674912217c121eb95be56d9feac = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;green&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_b815e08ac45bbe0c27a73bcd35e45588 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6d5b343e67ebb65a56138f8bd4a3e6d7 = $(`&lt;div id=&quot;html_6d5b343e67ebb65a56138f8bd4a3e6d7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;010-0101-2152 영업중&lt;/div&gt;`)[0];
#                 popup_b815e08ac45bbe0c27a73bcd35e45588.setContent(html_6d5b343e67ebb65a56138f8bd4a3e6d7);
#
#
#
#         marker_838199e560064c7be54ddea002d52ebf.bindPopup(popup_b815e08ac45bbe0c27a73bcd35e45588)
#         ;
#
#
#
#
#             marker_838199e560064c7be54ddea002d52ebf.bindTooltip(
#                 `&lt;div&gt;
#                      돈까스전문점
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#                 marker_838199e560064c7be54ddea002d52ebf.setIcon(icon_98e5f674912217c121eb95be56d9feac);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# # MarkerCluster

# %% [markdown]
# * 랜덤으로 위경도 좌표 100개 생성

# %%
N = 100
data = np.array(
[
np.random.uniform(low=36, high=38, size=N), # Random latitudes.
np.random.uniform(low=127, high=128, size=N), # Random longitudes.
] ).T
print(data[:3])
# Out:
# [[ 36.09643479 127.0505008 ]
#  [ 36.85211239 127.36718127]
#  [ 37.44834493 127.34536907]]

# %%
popups = [str(i) for i in range(N)] # Popups texts are simple numbers.
m = folium.Map([37.566345, 126.977893], zoom_start=8)
plugins.MarkerCluster(data, popups=popups).add_to(m)
m.save('./lec064_map_cluster.html')
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_e43d259a5c02fbe792255325cfbe79a2 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_e43d259a5c02fbe792255325cfbe79a2&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_e43d259a5c02fbe792255325cfbe79a2 = L.map(
#                 &quot;map_e43d259a5c02fbe792255325cfbe79a2&quot;,
#                 {
#                     center: [37.566345, 126.977893],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 8,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_2ff6b8eacd438b6401c1eacb30e0dd13 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_2ff6b8eacd438b6401c1eacb30e0dd13.addTo(map_e43d259a5c02fbe792255325cfbe79a2);
#
#
#             var marker_cluster_99a0a3240e44801ea069a1977703d1e2 = L.markerClusterGroup(
#                 {
# }
#             );
#
#
#             var marker_510c4b10114abdbbab2bb087afd49647 = L.marker(
#                 [36.09643478771499, 127.05050079897694],
#                 {
# }
#             ).addTo(marker_cluster_99a0a3240e44801ea069a1977703d1e2);
#
#
#         var popup_2e3c67ab6dfd2599c0130a18741f704e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a5d67a8c4ea3cb5f88f375fa9c671cee = $(`&lt;div id=&quot;html_a5d67a8c4ea3cb5f88f375fa9c671cee&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;0&lt;/div&gt;`)[0];
#                 popup_2e3c67ab6dfd2599c0130a18741f704e.setContent(html_a5d67a8c4ea3cb5f88f375fa9c671cee);
#
#
#
#         marker_510c4b10114abdbbab2bb087afd49647.bindPopup(popup_2e3c67ab6dfd2599c0130a18741f704e)
#         ;
#
#
#
#
#             var marker_82b532f60f61b66a48bd15bca9c09a9d = L.marker(
#                 [36.852112390726155, 127.36718127059855],
#                 {
# }
#             ).addTo(marker_cluster_99a0a3240e44801ea069a1977703d1e2);
#
#
#         var popup_5501b47bb0e7cf52b10704d5d9f5e9b9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_991b856f8b1674e637f2cdcf0ec6b512 = $(`&lt;div id=&quot;html_991b856f8b1674e637f2cdcf0ec6b512&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;1&lt;/div&gt;`)[0];
#                 popup_5501b47bb0e7cf52b10704d5d9f5e9b9.setContent(html_991b856f8b1674e637f2cdcf0ec6b512);
#
#
#
#         marker_82b532f60f61b66a48bd15bca9c09a9d.bindPopup(popup_5501b47bb0e7cf52b10704d5d9f5e9b9)
#         ;
#
#
#
#
#             var marker_5b0a6aa26e6c5a3b920466e5779e7cbf = L.marker(
#                 [37.448344930809796, 127.34536907170948],
#                 {
# }
#             ).addTo(marker_cluster_99a0a3240e44801ea069a1977703d1e2);
#
#
#         var popup_39dc40cde11481120f984637fd50ec49 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5dee64de8c0ae9e0eecb01da1cf19581 = $(`&lt;div id=&quot;html_5dee64de8c0ae9e0eecb01da1cf19581&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;2&lt;/div&gt;`)[0];
#                 popup_39dc40cde11481120f984637fd50ec49.setContent(html_5dee64de8c0ae9e0eecb01da1cf19581);
#
#
#
#         marker_5b0a6aa26e6c5a3b920466e5779e7cbf.bindPopup(popup_39dc40cde11481120f984637fd50ec49)
#         ;
#
#
#
#
#             var marker_6052bc1cea34c0805a4fcb0293abe970 = L.marker(
#                 [37.235228530890765, 127.67730163869346],
#                 {
# }
#             ).addTo(marker_cluster_99a0a3240e44801ea069a1977703d1e2);
#
#
#         var popup_90007f341a431a10e9e8de13d71bfb3d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5743c4a0b21e09580d372889617ff56b = $(`&lt;div id=&quot;html_5743c4a0b21e09580d372889617ff56b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;3&lt;/div&gt;`)[0];
#                 popup_90007f341a431a10e9e8de13d71bfb3d.setContent(html_5743c4a0b21e09580d372889617ff56b);
#
#
#
#         marker_6052bc1cea34c0805a4fcb0293abe970.bindPopup(popup_90007f341a431a10e9e8de13d71bfb3d)
#         ;
#
#
#
#
#             var marker_13e3f1ed7a63932

# %% [markdown]
# # GeoJSON
#
# * [대한민국 지역구 GeoJSON]
#     - https://sgis.kostat.go.kr/view/index
#     - https://github.com/raqoon886/Local_HangJeongDong
# * [서울시 열린데이터 광장] 주민등록인구수
#     - https://data.seoul.go.kr/dataList/419/S/2/datasetView.do
# * <b>import geopandas as gpd

# %% [markdown]
# ## Data Load

# %%
#! pip install geopandas

# %% [markdown]
# * <b>gpd.read_file("~~.json")

# %%
seoul_geo = gpd.read_file('datas/folium_map_data/lec12_seoul_geo_sigugun.json')
seoul_geo.head(2)
# Out:
# ---------------------------------------------------------------------------
# DataSourceError                           Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 seoul_geo = gpd.read_file('datas/folium_map_data/lec12_seoul_geo_sigugun.json')
#       2 seoul_geo.head(2)
#
# File C:\IT\workspace_python\.venv\lib\site-packages\geopandas\io\file.py:316, in _read_file(filename, bbox, mask, columns, rows, engine, **kwargs)
#     313             filename = response.read()
#     315 if engine == "pyogrio":
# --> 316     return _read_file_pyogrio(
#     317         filename, bbox=bbox, mask=mask, columns=columns, rows=rows, **kwargs
#     318     )
#     320 elif engine == "fiona":
#     321     if pd.api.types.is_file_like(filename):
#
# File C:\IT\workspace_python\.venv\lib\site-packages\geopandas\io\file.py:576, in _read_file_pyogrio(path_or_bytes, bbox, mask, rows, **kwargs)
#     567     warnings.warn(
#     568         "The 'include_fields' and 'ignore_fields' keywords are deprecated, and "
#     569         "will be removed in a future release. You can use the 'columns' keyword "
#    (...)
#     572         stacklevel=3,
#     573     )
#     574     kwargs["columns"] = kwargs.pop("include_fields")
# --> 576 return pyogrio.read_dataframe(path_or_bytes, bbox=bbox, **kwargs)
#
# File C:\IT\workspace_python\.venv\lib\site-packages\pyogrio\geopandas.py:382, in read_dataframe(path_or_buffer, layer, encoding, columns, read_geometry, force_2d, skip_features, max_features, where, bbox, mask, fids, sql, sql_dialect, fid_as_index, use_arrow, on_invalid, arrow_to_pandas_kwargs, datetime_as_string, mixed_offsets_as_utc, **kwargs)
#     374 gdal_force_2d = False if use_arrow else force_2d
#     376 # Always read datetimes as string values to preserve (mixed) time zone info
#     377 # correctly. If arrow is not used, it is needed because numpy does not
#     378 # directly support time zones + performance is also a lot better. If arrow
#     379 # is used, needed because datetime columns don't support mixed time zone
#     380 # offsets + e.g. for .fgb files time zone info isn't handled correctly even
#     381 # for unique time zone offsets if datetimes are not read as string.
# --> 382 result = read_func(
#     383     path_or_buffer,
#     384     layer=layer,
#     385     encoding=encoding,
#     386     columns=columns,
#     387     read_geometry=read_geometry,
#     388     force_2d=gdal_force_2d,
#     389     skip_features=skip_features,
#     390     max_features=max_features,
#     391     where=where,
#     392     bbox=bbox,
#     393     mask=mask,
#     394     fids=fids,
#     395     sql=sql,
#     396     sql_dialect=sql_dialect,
#     397     return_fids=fid_as_index,
#     398     datetime_as_string=True,
#     399     **kwargs,
#     400 )
#     402 if use_arrow:
#     403     import pyarrow as pa
#
# File C:\IT\workspace_python\.venv\lib\site-packages\pyogrio\raw.py:200, in read(path_or_buffer, layer, encoding, columns, read_geometry, force_2d, skip_features, max_features, where, bbox, mask, fids, sql, sql_dialect, return_fids, datetime_as_string, **kwargs)
#      59 """Read OGR data source into numpy arrays.
#      60
#      61 IMPORTANT: non-linear geometry types (e.g., MultiSurface) are converted
#    (...)
#     196
#     197 """
#     198 dataset_kwargs = _preprocess_options_key_value(kwargs) if kwargs else {}
# --> 200 return ogr_read(
#     201     get_vsi_path_or_buffer(path_or_buffer),
#     202     layer=layer,
#     203     encoding=encoding,
#     204     columns=columns,
#     205     read_geometry=read_geometry,
#     206     force_2d=force_2d,
#     207     skip_features=skip_features,
#     208     max_features=max_features or 0,
#     209     where=where,
#     210     bbox=bbox,
#     211     mask=_mask_to_wkb(mask),
#     212     fids=fids,
#     213     sql=sql,
#     214     sql_dialect=sql_dialect,
#     215     return_fids=return_fids,
#     216     dataset_kwargs=dataset_kwargs,
#     217     datetime_as_string=datetime_as_string,
#     218 )
#
# File pyogrio/_io.pyx:1412, in pyogrio._io.ogr_read()
#
# File pyogrio/_io.pyx:262, in pyogrio._io.ogr_open()
#
# DataSourceError: datas/folium_map_data/lec12_seoul_geo_sigugun.json: No such file or directory

# %% [markdown]
# * <b>pd.read_csv("~~.csv")

# %%
seoul_ingu = pd.read_csv("datas/folium_map_data/lec12_주민등록인구_20230222161234.csv"
                  , encoding="cp949"
                  , sep = "\t"   
                 )
seoul_ingu.head(2)

# %%
seoul_ingu.info()

# %% [markdown]
# ## Choropleth maps

# %%
# 지도 중심 위치
m = folium.Map(location=[37.562225, 126.978555], tiles="OpenStreetMap", zoom_start=10)

# Choropleth 계층 추가 (※ folium.Map이 아닌 folium.Choropleth!)
folium.Choropleth(
    geo_data=seoul_geo,               # GeoJSON 파일 또는 dict
    data=seoul_ingu,                  # 데이터프레임
    key_on='feature.properties.name', # GeoJSON과 매핑할 key
    
    name='인구밀도',                  # 레이어 이름
    columns=['동별', '총계'],         # [매핑 key, 값]
    #fill_color='Blues',              # 단일 색상 스킴 ('YlGn', 'BuPu', 'Reds' 등)
    fill_color=  'Blues' if seoul_geo["code"].str == '11250' else 'Reds',      # 'Blues',
    fill_opacity=0.7,
    line_opacity=0.3,
    line_color='gray',                # 윤곽선 색
    legend_name='인구 총계'
).add_to(m)

# 마우스 위치 플러그인 추가
plugins.MousePosition().add_to(m)

# 결과 지도 표시 또는 저장
m.save("seoul_population.html")
m
# webbrowser.open_new("folium_kr.html")

# %% [markdown]
# ## Folium Map

# %%
import json
with open('datas/folium_map_data/lec12_seoul_geo_sigugun.json', mode='rt', encoding='utf-8') as f:
    geo = json.loads(f.read())
    f.close()

map = folium.Map(location=[37.562225, 126.978555], tiles="OpenStreetMap", zoom_start=10)
    
folium.GeoJson(
    geo,
    name='seoul_municipalities'
).add_to(map)
map

# %% [markdown]
# # 위경도 -- 주소 변환
# * https://console.cloud.google.com/apis/credentials?project=kdigital-378601
# * API 및 서비스 > 라이브러리 > 사용체크
#     * Maps Javascript API
#     * Geocoding API
# * 구글 클라우드 콘솔 API 키 발급
#     *  API 및 서비스 > 사용자인증장보 > API키
# * <b> pip install googlemaps, geocoder

# %%
# ! pip install googlemaps
# ! pip install geocoder

# %% [markdown]
# ### API_KEY

# %%
MY_GOOGLE_API_KEY___ = 'AIzaSyABtRl1XZfH98dIZE5M1nVS2XiYrsQQDVY'

# %% [markdown]
# ## 지명,주소 --> 위경도좌표 변환
# * <b>res_dict = googlemaps.Client(key='AIza').geocode("지명")

# %%
import googlemaps
import pprint
gmaps = googlemaps.Client(key=MY_GOOGLE_API_KEY___)
res_dict = gmaps.geocode(('제주국제공항'), language='ko')
lat = res_dict[0]['geometry']['location']['lat']
lng = res_dict[0]['geometry']['location']['lng']
print(lat, lng)
print("--"*30)
pprint.pprint(res_dict)

# %% [markdown]
# ## 위경도좌표 --> 주소 변환
# * <b>res_dict = googlemaps.Client(key='AIza').reverse_geocode(  (위도,경도)   )

# %%
import googlemaps
import pprint
gmaps = googlemaps.Client(key=MY_GOOGLE_API_KEY___)
reverse_geocode_result = gmaps.reverse_geocode((33.389101, 126.526930),  language="ko")

print(reverse_geocode_result[0]['formatted_address'])
print("--"*30)
pprint.pprint(reverse_geocode_result)

# %% [markdown]
# # 실습 : 제주관광

# %% [markdown]
# ## CircleMarker

# %%
# 지도 객체 생성
m = folium.Map(location=[33.389101, 126.526930], zoom_start=10, tiles='OpenStreetMap') 

folium.Marker([33.38916956702278, 126.52507782297765], popup='한라산').add_to(m)
folium.Marker([33.510619228109334, 126.49137485480217], popup='제주국제공항',
              icon=folium.Icon(color='red',icon='info-sign')).add_to(m)

folium.CircleMarker([33.38916956702278, 126.52507782297765], radius=100
                    ,color='#3186cc', fill_color='#3186cc', popup='제주국제공항').add_to(m)
m

# %% [markdown]
# ## 좌표변환 활용

# %%
df = pd.DataFrame(data=[  ['제주국제공항','제주특별자치도 제주시 공항로 2','000-000-0000',.0, .0],
                          ['제주칼호텔','특별자치도 제주시 중앙로 151','111-111-1111',.0, .0],
                          ['제주맛집칼국수','제주특별자치도 제주시 조천읍 비자림로685','333-333-3333',.0, .0],
                         ],
                         columns=['store','addr','tel','lat','lng']
                 )
df.head()

# %% [markdown]
# * by 규리

# %%
import googlemaps
import pprint
gmaps = googlemaps.Client(key=MY_GOOGLE_API_KEY___)

lat = []
lng = []
for addr in df['addr'] :
    res_dict = gmaps.geocode((addr), language='ko')
    lat.append(res_dict[0]['geometry']['location']['lat'])
    lng.append(res_dict[0]['geometry']['location']['lng']) 
df['lat'] = lat
df['lng'] = lng
df

# %% [markdown]
# * by 세영

# %%
len(df['addr'])

# %%
for i in range(  len(df['addr'])  ):   #i  == 0 , 1 , 2
    addr = df.loc[i, 'addr']
    res_dict = gmaps.geocode((addr), language='ko')
    lat = res_dict[0]['geometry']['location']['lat']
    lng = res_dict[0]['geometry']['location']['lng']
    df.loc[i, 'lat'] = lat
    df.loc[i, 'lng'] = lng
df

# %% [markdown]
# * by 재현

# %%
for i in range( len(df['addr'])  ) :
    res_dict = gmaps.geocode((df['addr'][i]), language='ko')
    df['lat'][i] = res_dict[0]['geometry']['location']['lat']
    df['lng'][i] = res_dict[0]['geometry']['location']['lng']
df

# %%
for i in range( len(df['addr']) ) :
    res_dict = gmaps.geocode((df['addr'][i]), language='ko')
    for j in ['lat', 'lng'] :
        df[j][i] = res_dict[0]['geometry']['location'][j]
df

# %% [markdown]
# * by 명래

# %%
df["lat"] = df["addr"].transform(lambda addr: gmaps.geocode(addr, language='ko')[0]['geometry']['location']['lat'])
df["lng"] = df["addr"].transform(lambda addr: gmaps.geocode(addr, language='ko')[0]['geometry']['location']['lng'])
df

# %%
df["lat"].mean(), df["lng"].mean()

# %%
df.loc[0, "lat"],  df.loc[0, "lng"]

# %% [markdown]
# ## 마커찍기

# %% [markdown]
# ### folium.Marker( (위도,경도) )

# %%
m = folium.Map(location=(df["lat"].mean(), df["lng"].mean()) , zoom_start=11)
for i in range( len(df) ) : #0, 1 ,2
    folium.Marker(
        location=[ df.loc[i, "lat"],  df.loc[i, "lng"]  ],
        tooltip=df.loc[i, "store"]
    ).add_to(m)
m

# %% [markdown]
# ### folium.MarkerCluster( [(위도,경도) ...] )

# %%
df[['lat','lng']].values.tolist()

# %%
tooltip = df['store'].values
m = folium.Map([df["lat"].mean(), df["lng"].mean()], zoom_start=8)
plugins.MarkerCluster(df[['lat','lng']].values.tolist()).add_to(m)
m

# %%
m = folium.Map(location=[df['lat'].mean(), df['lng'].mean()], zoom_start=10)

# Map에 빈 객체 MarkerCluster 올리기
marker_cluster = plugins.MarkerCluster().add_to(m)

# 개별 마커를 추가하면서 tooltip 설정
for idx, row in df.iterrows():
    folium.Marker(
        location=[row['lat'], row['lng']],
        tooltip=row['store']
    ).add_to(marker_cluster)
m

# %% [markdown]
# ### 연습 : df.iterrows() vs. df.itertuples() vs. enumerate()
# * <font size=4 color=red><b> iterrows() : 행을 시리즈로 반환
# * <font size=4 color=red><b> itertuples() : 행반환
# * <font size=4 color=red><b> enumerate() : i번째, 행반환

# %% [markdown]
# #### <b>Series 연습

# %%
s = df.iloc[0]
s

# %%
# df.iloc[0]["lat"]
s["lat"], s.lat

# %%
#s.loc["lat", :]
s.loc["lat"]

# %% [markdown]
# #### <b> df.iterrows()
# *  ( 0 ,  시리즈 )

# %%
for s in df.iterrows() :
    print(s)

# %%
# for s in df.iterrows() :
#     print(s)
m = folium.Map(location=(df["lat"].mean(), df["lng"].mean()) , zoom_start=11)

for i, s in df.iterrows() :
    print(i)
    print(s)
    print(s["lat"], s["lng"])

    folium.Marker(
        location=[ s["lat"], s["lng"]  ],
        tooltip=s["store"]
    ).add_to(m)
#m

# %% [markdown]
# #### <b> df.itertuples()
# * Pandas(Index=0, 컬럼1='값' , 컬럼2='값' ...)

# %%
for t in df.itertuples() :
    print(t)

# %%
m = folium.Map(location=(df["lat"].mean(), df["lng"].mean()) , zoom_start=11)
for t in df.itertuples() :
    print(t.Index)
    print(t.lat)

    folium.Marker(
        location=[ t.lat, t.lng ],
        tooltip=t.store
    ).add_to(m)
#m

# %% [markdown]
# #### <b> enumerate( df["컬럼"] )
# * (0, 값)

# %%
for v in enumerate(df["lat"]) : 
    print(v)

# %%
for i, v in enumerate(df["lat"]) : 
    print(i, v)

# %%
for i, v in enumerate(df[["lat","lng"]].itertuples()) : 
    print(i, v)

# %% [markdown]
# ### 연습 : for

# %% [markdown]
# #### <b>기초 for

# %%
df[['lat','lng']].values

# %%
m = folium.Map(location=(df["lat"].mean(), df["lng"].mean()) , zoom_start=11)
for v in df[['lat','lng','store']].values:
    print(v)
    print(v[0], v[1], v[2])

    folium.Marker(
        location=[ v[0], v[1] ],
        tooltip=v[2]
    ).add_to(m)
#m

# %% [markdown]
# #### <b>★★★강추
# <pre><font color=red><b>for v in df[['lat','lng']].values:
#     folium.Marker(  location=v  ).add_to(m)

# %%
for v in df[['lat','lng']].values:
    print(v)       #[위도, 경도]
    folium.Marker( location=v ).add_to(m)
# m

# %%
for v1, v2 in df[['lat','lng']].values:
    print(v1, v2)

# %%
def myprint(a,b) :
    return a+b, a*b

res = myprint(3,4)    
print(res)
print(res[0], res[1])

res1, res2 = myprint(3,4)    
print(res1, res2)

# %% [markdown]
# #### <b>컨프리헨션

# %%
for i in [1,2,3] : 
    print(i)

# %%
[ print(i) for i in [1,2,3]   ]

# %%
[ folium.Marker(  location=v  ).add_to(m) for v in df[['lat','lng']].values  ]
#m

# %%
[ folium.Marker(  location=[t.lat, t.lng]  ).add_to(m)  for t in df.itertuples() ]
# m

# %%
[ folium.Marker(  location=v ).add_to(m) for v in  zip (df["lat"], df["lng"]) ]
#m

# %% [markdown]
# #### <b>df.to_dict("records")

# %%
df[["lat", "lng"]].to_dict("records")

# %%
for  dic in df[["lat", "lng"]].to_dict("records") :
    print(dic)
    folium.Marker(  location=[dic["lat"], dic["lng"]] ).add_to(m)
#m

# %% [markdown]
# #### <b>df.apply(lambda x:)

# %%
df.apply(lambda x: folium.Marker(  location=[x["lat"], x["lng"]] ).add_to(m) , axis=1 )
#m

# %% [markdown]
# #### <b>zip ([위도],[경도])
# * [ (위도1, 경도1) , (위도2, 경도2)  ... ] = zip ([위도],[경도])

# %%
zip (["a","b","c"], [1,2,3])

# %%
list(   zip (["a","b","c"], [1,2,3])   )

# %%
for v in  zip (df["lat"], df["lng"]) :
    print(v)
    folium.Marker(  location=v ).add_to(m)
#m

# %% [markdown]
# ## 맛집찾기

# %% [markdown]
# ### 정규표현식(Regex)
# * import re
# <img src="https://img1.daumcdn.net/thumb/R1280x0/?scode=mtistory2&fname=https%3A%2F%2Ft1.daumcdn.net%2Fcfile%2Ftistory%2F99CE98335DB3C23F11" width=300>

# %% [markdown]
# ### Data Load

# %%
df = pd.read_csv("datas/folium_map_data/제주관광공사_여행장소_20220322.csv", encoding="cp949")
df.head(2)

# %% [markdown]
# ### 제주특별자치도 ~ 만 추출

# %%
df.shape

# %% [markdown]
# #### <font color=red size=5><b>★★★강추 ::::df['컬럼'].str.startswith()

# %% [markdown]
# #### <b>방법1) df['컬럼'].str.startswith() 사용

# %%
"ABCdefg".startswith("ABC")

# %%
jeju_df = df[df['지번주소'].str.startswith('제주특별자치도', na=False)]
print(jeju_df.shape)
jeju_df.head(3)

# %% [markdown]
# #### <b>방법2) 정규표현식 사용

# %%
def myAddrCheck(addr) : 
    #if addr is not None and addr != "":
    if isinstance(addr, str):   #type(addr) == str
        return re.match(r'제주특별자치도', addr)
    else : 
        return None
jeju_df = df[df['지번주소'].apply(lambda x:  myAddrCheck(x)).notnull()]
print(jeju_df.shape)
jeju_df.head(3)

# %%
jeju_df = df[df['지번주소'].apply(lambda x: pd.notna(x) and re.match(r'^제주특별자치도', x)).notnull()]
print(jeju_df.shape)
jeju_df.head(3)

# %% [markdown]
# #### <b>인덱스 재정렬

# %%
jeju_df.index

# %%
jeju_df = jeju_df.reset_index(drop=True)

# %%
jeju_df.index

# %%
print(jeju_df.shape)
jeju_df.head(3)

# %% [markdown]
# ### 지번주소 자르기

# %% [markdown]
# #### <font color=red size=6><b>★★★강추 :::: df['컬럼'].str.extract(정규표현식)

# %% [markdown]
# #### <b>방법1) df['컬럼'].str.extract(정규표현식) 사용

# %%
pattern = r'제주특별자치도\s+(\w+)\s+(.*)'
jeju_df[['주소1', '주소2']] = jeju_df['지번주소'].str.extract(pattern)
print(jeju_df.shape)
jeju_df.head(3)

# %% [markdown]
# #### <b>방법2) 정규표현식 사용

# %%
jeju_df["지번주소"]

# %%
pattern = r'제주특별자치도\s+(\w+)\s+(.*)'

def extract_주소1(x):
    if isinstance(x, str):
        res = re.match(pattern, x)
        if res:
            return res.group(1)
    return None

def extract_주소2(x):
    if isinstance(x, str):
        res = re.match(pattern, x)
        if res:
            return res.group(2)
    return None

jeju_df['주소1'] = jeju_df['지번주소'].apply(lambda x : extract_주소1(x))
jeju_df['주소2'] = jeju_df['지번주소'].apply(extract_주소2)

print(jeju_df.shape)
jeju_df.head()

# %%
pattern = r'제주특별자치도\s+(\w+)\s+(.*)'
jeju_df['주소1'] = jeju_df['지번주소'].apply(lambda x: re.match(pattern, x).group(1) if isinstance(x, str) and re.match(pattern, x) else None)
jeju_df['주소2'] = jeju_df['지번주소'].apply(lambda x: re.match(pattern, x).group(2) if isinstance(x, str) and re.match(pattern, x) else None)
print(jeju_df.shape)
jeju_df.head(3)

# %% [markdown]
# #### <b>방법3) df['컬럼'].str.split(" ")

# %%
res = "제주특별자치도 제주시 우도면 연평리 2609".split(" ")
print(res)
print(res[0])
print(res[1])
print(res[2:])
print(" ".join(res[2:]))

# %%
jeju_df["주소1"] = ""
jeju_df["주소2"] = ""
for i in range(len(jeju_df)):
    addr =  jeju_df.loc[i,"지번주소"]
    if isinstance(addr, str):
        res = addr.split(" ")
        jeju_df.loc[i,"주소1"] = res[1]
        jeju_df.loc[i,"주소2"] = " ".join(res[2:])
    else : 
        jeju_df.loc[i, "주소1"] = None
        jeju_df.loc[i, "주소2"] = None
print(jeju_df.shape)        
jeju_df.head(2)
