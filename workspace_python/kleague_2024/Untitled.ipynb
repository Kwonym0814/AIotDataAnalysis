# %%
# ! pip install pandas
# Out:
# ...
#    ---------------------------------------- 0.0/11.3 MB ? eta -:--:--
#    -------- ------------------------------- 2.4/11.3 MB 11.2 MB/s eta 0:00:01
#    ---------------- ----------------------- 4.7/11.3 MB 11.9 MB/s eta 0:00:01
#    ---------------------- ----------------- 6.3/11.3 MB 10.2 MB/s eta 0:00:01
#    ------------------------------ --------- 8.7/11.3 MB 10.5 MB/s eta 0:00:01
#    ---------------------------------------  11.3/11.3 MB 10.8 MB/s eta 0:00:01
#    ---------------------------------------- 11.3/11.3 MB 10.6 MB/s eta 0:00:00
# ...
#
#    ---------------------------------------- 0/2 [pytz]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
# ...

# %%
import pandas as pd

# %%
raw_data = pd.read_csv('raw_data.csv')

# %%
raw_data.head()
# Out:
#    game_id  action_id  period_id  time_seconds  team_id  player_id  \
# 0   126288          0          1         1.033     2353   356625.0
# 1   126288          1          1         2.433     2353   356612.0
# 2   126288          2          1         3.033     2353   356612.0
# 3   126288          3          1         4.333     2353   356618.0
# 4   126288          4          1         4.900     2353   356618.0
#
#   result_name    start_x    start_y      end_x      end_y         dx  \
# 0  Successful  52.670205  34.919632  68.628945  34.347412  15.958740
# 1         NaN  68.628945  34.347412  68.628945  34.347412   0.000000
# 2  Successful  68.228055  33.853256  65.468865  26.640292  -2.759190
# 3         NaN  65.468865  26.640292  65.468865  26.640292   0.000000
# 4  Successful  64.838025  26.766636  63.300510  43.018024  -1.537515
#
#           dy      type_name player_name_ko team_name_ko position_name  \
# 0  -0.572220           Pass            이영준  김천 상무 프로축구단            CF
# ...

# %%
pass_received = raw_data.loc[raw_data['type_name']=='Pass Received',
    ["game_id", "period_id", "team_id", "player_id", "result_name", "type_name", "player_name_ko", "team_name_ko", "position_name", "main_position"]]
pass_received.head()
# Out:
#     game_id  period_id  team_id  player_id result_name      type_name  \
# 1    126288          1     2353   356612.0         NaN  Pass Received
# 3    126288          1     2353   356618.0         NaN  Pass Received
# 5    126288          1     2353   356624.0         NaN  Pass Received
# 8    126288          1     2353   356612.0         NaN  Pass Received
# 11   126288          1     2353   356619.0         NaN  Pass Received
#
#    player_name_ko team_name_ko position_name main_position
# 1             원두재  김천 상무 프로축구단           CDM            CM
# 3             김진규  김천 상무 프로축구단            CM            CM
# 5             강현묵  김천 상무 프로축구단            CM            CM
# 8             원두재  김천 상무 프로축구단           CDM            CM
# 11            김재우  김천 상무 프로축구단            CB            CB

# %%
raw_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 579306 entries, 0 to 579305
# Data columns (total 18 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   game_id         579306 non-null  int64
#  1   action_id       579306 non-null  int64
#  2   period_id       579306 non-null  int64
#  3   time_seconds    579306 non-null  float64
#  4   team_id         579306 non-null  int64
#  5   player_id       579305 non-null  float64
#  6   result_name     229702 non-null  object
#  7   start_x         579306 non-null  float64
#  8   start_y         579306 non-null  float64
#  9   end_x           579306 non-null  float64
#  10  end_y           579306 non-null  float64
#  11  dx              579306 non-null  float64
#  12  dy              579306 non-null  float64
#  13  type_name       579306 non-null  object
#  14  player_name_ko  579305 non-null  object
#  15  team_name_ko    579306 non-null  object
# ...
